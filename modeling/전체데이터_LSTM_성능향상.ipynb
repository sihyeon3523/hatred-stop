# %%
import pandas as pd
import numpy as np

import re
from tqdm import tqdm
from konlpy.tag import Okt

# %%
train = pd.read_csv('data/unsmile_train_new.csv')
test = pd.read_csv('data/unsmile_valid_new.csv')

# %%
train.drop_duplicates(subset = ['문장'], inplace=True) # document 열에서 중복인 내용이 있다면 중복 제거
train['문장'] = train['문장'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
train['문장'] = train['문장'].str.replace('^ +', "") # 공백은 empty 값으로 변경
train['문장'].replace('', np.nan, inplace=True) # 공백은 Null 값으로 변경
train = train.dropna(how='any') # Null 값 제거
print('전처리 후 테스트용 샘플의 개수 :',len(train))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 22479
# /var/folders/j7/1z0h6p4d553cqf5_7bw8dym00000gn/T/ipykernel_77106/198297000.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   train['문장'] = train['문장'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
# /var/folders/j7/1z0h6p4d553cqf5_7bw8dym00000gn/T/ipykernel_77106/198297000.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   train['문장'] = train['문장'].str.replace('^ +', "") # 공백은 empty 값으로 변경

# %%
test.drop_duplicates(subset = ['문장'], inplace=True) # document 열에서 중복인 내용이 있다면 중복 제거
test['문장'] = test['문장'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
test['문장'] = test['문장'].str.replace('^ +', "") # 공백은 empty 값으로 변경
test['문장'].replace('', np.nan, inplace=True) # 공백은 Null 값으로 변경
test = test.dropna(how='any') # Null 값 제거
print('전처리 후 테스트용 샘플의 개수 :',len(test))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 5592
# /var/folders/j7/1z0h6p4d553cqf5_7bw8dym00000gn/T/ipykernel_77106/1308857970.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   test['문장'] = test['문장'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
# /var/folders/j7/1z0h6p4d553cqf5_7bw8dym00000gn/T/ipykernel_77106/1308857970.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   test['문장'] = test['문장'].str.replace('^ +', "") # 공백은 empty 값으로 변경

# %%
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
okt = Okt()

# %%
X_train = []
for sentence in tqdm(train['문장']):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_train.append(stopwords_removed_sentence)
# Out:
# 100%|████████████████████████████████████| 22479/22479 [00:35<00:00, 633.68it/s]

# %%
X_test = []
for sentence in tqdm(test['문장']):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_test.append(stopwords_removed_sentence)
# Out:
# 100%|██████████████████████████████████████| 5592/5592 [00:08<00:00, 625.16it/s]

# %%
from keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)
tokenizer.fit_on_texts(X_test)

# %%
X_train
# Out:
# [['이다', '시간', '쉬다', '그렇다', '아니다'],
#  ['아동',
#   '성범죄',
#   '페도버',
#   '기록',
#   '바',
#   '끊어지다',
#   '영원하다',
#   '고통',
#   '받다',
#   '무슬림',
#   '퍼',
#   '근',
#   '친',
#   '이다',
#   '까지',
#   '떨어지다',
#   '출산',
#   '위험',
#   '다'],
#  ['루나',
#   '솔로',
#   '앨범',
#   '나오다',
#   '때',
#   '부터',
#   '머모',
#   '기운',
#   '있다',
#   'ㅇㅇ',
#   '진짜',
#   '띵곡임',
#   '꼭',
#   '들다',
#   '보다'],
#  ['홍팍',
#   '에도',
#   '어버이연합',
#   '인가',
#   '보내다',
#   '뭐',
#   '이런',
#   '뎃글',
#   '있다',
#   '거',
#   '어버이연합',
#   '측',
#   '신고',
#   '그',
#   '쪽',
#   '에서',
#   '고소',
#   '가능하다'],
#  ['아',
#   '놓다',
#   '왜',
#   '여기',
#   '댓',
#   '다',
#   '여자',
#   '김치',
#   '녀',
#   '라고',
#   '먼저',
#   '불리다',
#   '여자',
#   '더',
#   '심하다',
#   '그렇다',
#   '이렇게',
#   '개',
#   '로',
#   '싸우다',
#   '내',
#   '볼',
#   '땐',
#   '두다',
#   '나쁘다',
#   '말',
#   '그',
#   '이상',
#   '이하',
#   '아니다'],
#  ['고',
#   '향가',
#   '서',
#   '피방',
#   '가면',
#   '동네',
#   '부럴',
#   '친구',
#   '이랑은',
#   '뭐',
#   '거르',
#   '거',
#   '없이',
#   '이야기',
#   '막',
#   '말',
#   '되다',
#   '당연하다',
#   '키',
#   '보드',
#   '치다',
#   '그렇다',
#   '않다',
#   '말',
#   '많이',
#   '거치다',
#   '해',
#   '반성'],
#  ['예수',
#   '십',
#   '새끼',
#   '개새끼',
#   '창녀',
#   '아들',
#   '애비',
#   '실종',
#   '가정교육',
#   '못',
#   '받다',
#   '무뇌충',
#   '허언증',
#   '정신병',
#   '사기꾼',
#   '망상',
#   '근본',
#   '없다',
#   '병신',
#   '장애인',
#   '짱개',
#   '흑인',
#   '이슬람',
#   '전라도',
#   '랑',
#   '동',
#   '급'],
#  ['나이', '치다', '먹다', '피시방', '가다', '놈', '대가리', '똥', '만찬', '놈', '들이다'],
#  ['출산',
#   '청',
#   '같다',
#   '소리',
#   '우리나라',
#   '계집',
#   '다',
#   '의무',
#   '적',
#   '군대',
#   '보내다',
#   '해결',
#   '되다',
#   '일이',
#   '다',
#   '정신',
#   '개조',
#   '부터',
#   '시키다',
#   '지다',
#   '다',
#   '하고',
#   '무슨',
#   '애',
#   '낳다',
#   '무슨',
#   '자식',
#   '교육',
#   '을'],
#  ['재능', 'ㅂㅅㅌㅊ', '노', 'ㅋㅋㅋㅋㅋ', '나다', '합성', '배우다'],
#  ['가짜', '남자', '어떻다', '생기다'],
#  ['이슬람', '뺨', '치다'],
#  ['아',
#   '어린이집',
#   '월요일',
#   '데리다',
#   '금요일',
#   '데리',
#   '고',
#   '오다',
#   '아',
#   '가슴',
#   '너무',
#   '아프다',
#   '작',
#   '살',
#   '아가',
#   '얼마나',
#   '외롭다',
#   '아'],
#  ['갓슬람',
#   '정희',
#   '구현',
#   '테러',
#   'ㅅㅅㅅㅅ',
#   '미제',
#   '양키',
#   '새끼',
#   '에게는',
#   '테러',
#   '답',
#   '이다',
#   '좆',
#   '같다',
#   '양키',
#   '씨발',
#   '새끼'],
#  ['따다', '넘어가다', '보다'],
#  ['원',
#   '리더십',
#   '원',
#   '메시지',
#   '로',
#   '내부',
#   '결속',
#   '을',
#   '더',
#   '강화하다',
#   '외부',
#   '로',
#   '리마커블',
#   '이미지',
#   '구축',
#   '다시',
#   '교회',
#   '로',
#   '모',
#   '일수',
#   '있다',
#   '소망',
#   '하고',
#   '기',
#   '도합',
#   '니',
#   '다'],
#  ['협박', '스킬', '패', '시브', '랑께'],
#  ['위로',
#   '격려',
#   '호텔',
#   '에서',
#   '해',
#   '왜',
#   '저',
#   '여자도',
#   '정상',
#   '아니다',
#   '완전',
#   '지네',
#   '할아버지',
#   '보다',
#   '나이',
#   '더',
#   '많다',
#   '데',
#   '토나오다',
#   '같다',
#   '두다',
#   '미치다',
#   '그렇게',
#   '더럽다',
#   '짓다',
#   '설교',
#   '어떻다',
#   '웩'],
#  ['메틸',
#   '알콜',
#   '집',
#   '에서',
#   '쓰다',
#   '있다',
#   '질문',
#   '받다',
#   '프로',
#   '에틸',
#   '프로',
#   '메틸',
#   '들어가다',
#   '공업',
#   '용',
#   '에틸',
#   '알콜',
#   '면세',
#   '라',
#   '불법',
#   '적',
#   '술',
#   '제조',
#   '때문',
#   '프로',
#   '정도',
#   '메틸',
#   '들어가다',
#   '제',
#   '조방',
#   '지용',
#   '쓴다'],
#  ['띄우다', '사람', '진짜', '없다', '없다'],
#  ['한국', '패', '미고', '유정', '수준', 'ㅋㅋㅋ'],
#  ['구', '구', '절절', '팩트'],
#  ['쑈', '빼다', '아무', '것', '없다', '개돼지', '정권', '이노', '탄핵', '개힘', '조'],
#  ['진짜',
#   '저',
#   '것',
#   '아주',
#   '싫다',
#   '싫다',
#   '내',
#   '외국',
#   '년놈',
#   '에게',
#   '욕질',
#   '괜히',
#   '해대',
#   '게',
#   '아니다'],
#  ['이슬람', '이고', '뭐', '고', '그냥', '종교', '충', '다', '죽다', '좋다'],
#  ['홍어', '무치다', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['안티',
#   '페미',
#   '울다',
#   '전',
#   '우리나라',
#   '에서',
#   '페미',
#   '라고',
#   '설치다',
#   '작자',
#   '어떻다',
#   '설치',
#   '고',
#   '다니다',
#   '직시',
#   '해보다',
#   '우선',
#   '인',
#   '것',
#   '같다',
#   'ㅋㅋㅋ'],
#  ['뭐',
#   '기업',
#   '이네',
#   '기업',
#   '이여',
#   '기업',
#   '돈',
#   '갖다',
#   '받치다',
#   '어이없다',
#   '시',
#   '키',
#   '문제',
#   '다'],
#  ['홍', '피', '폭', 'ㅎㅎㅎ'],
#  ['안', '희다', '정민아', '왜', '저깄노', 'ㅋㅋㅋㅋ'],
#  ['큰일',
#   '나다',
#   '저',
#   '글',
#   '쓸다',
#   '자댕',
#   '이를',
#   '재기',
#   '로',
#   '위장',
#   '죽이다',
#   '방법',
#   '보내다',
#   '보다',
#   '이기',
#   '야'],
#  ['진씨', '왜', '반말', '이야'],
#  ['교회',
#   '다니다',
#   '보다',
#   '교인',
#   '보이다',
#   '집중',
#   '하고',
#   '그',
#   '말',
#   '속세',
#   '사람',
#   '보다',
#   '가식',
#   '적임',
#   '그리고',
#   '굉장하다',
#   '이분법',
#   '적',
#   '사고',
#   '갖다',
#   '아마',
#   '이런',
#   '상황',
#   '에서',
#   '예배',
#   '드리다',
#   '우선',
#   '순위',
#   '지키다',
#   '자뻑',
#   '하고',
#   '있다',
#   '임',
#   '개뿔',
#   '하나님',
#   '그렇다',
#   '기적',
#   '이고',
#   '천박하다',
#   '신앙',
#   '을',
#   '원',
#   '치',
#   '않다',
#   '거',
#   '다',
#   '개독',
#   '아'],
#  ['사망', '이후', '조사', '받다', '전', '까지', '분', '통화', '내', '역', '확인', '필요'],
#  ['뜬구름', '잡다', '소리', '있다'],
#  ['새끼', '전라도'],
#  ['도대체', '정권', '에서', '무고', '목숨', '얼마나', '죽다'],
#  ['진짜', '전라도', '존나', '싫다'],
#  ['돈고', '질병', '이다', '이기', '야'],
#  ['보지', '딱하다', '저런', '거', '대해', '자존심', '같다', '걸', '안', '느끼다', '않다'],
#  ['오', '세', '라비', '님', '페미니스트', '아니다'],
#  ['뉴스', '보', '니까', '길이', '낯설다', '않다'],
#  ['동성애', '저주', '야'],
#  ['애',
#   '먹이',
#   '게',
#   '돈가스',
#   '달라',
#   '건',
#   '뭐',
#   '야',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '아니다',
#   '애',
#   '먹다',
#   '돈가스',
#   '어디',
#   '하늘',
#   '에서',
#   '뚝',
#   '떨어지다',
#   '양심',
#   '없다',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['맞다', '저', '멘트', '로', '타격', '느끼다', '개념', '려둘', '뿐', '이다', 'ㅋㅋㅋㅋㅋ'],
#  ['내다', '들다', '기', '싸움', '더하다'],
#  ['마포', '뭘뜻'],
#  ['전라도', '피다', '물', '보다', '진하다'],
#  ['카스', '머임', '상', '폐', '보지', '중', '부패하다', '보지', '임'],
#  ['솔직하다',
#   '패',
#   '죽이다',
#   '수',
#   '있다',
#   '정당방위',
#   '상황',
#   '에서',
#   '어디',
#   '어떻다',
#   '치다',
#   '병신',
#   '만들다',
#   '시뮬레이션',
#   '많이',
#   '해보다'],
#  ['저', '남자', '랑', '섹스', '쎅스쌕스'],
#  ['존나', '무섭다'],
#  ['물',
#   '타다',
#   '애초',
#   '지금',
#   '개독',
#   '존나',
#   '끄다',
#   '진화론',
#   '관련',
#   '글',
#   '올라오다',
#   '개독',
#   '새끼',
#   '창조설',
#   '가져오다',
#   '빼애애애',
#   'ㅐ',
#   '액',
#   '시작',
#   '된거',
#   '다'],
#  ['지금', '이미', '난리', '남'],
#  ['거식증',
#   '때문',
#   '되다',
#   '적다',
#   '학',
#   '식다',
#   '인데',
#   '언덕',
#   '위',
#   '있다',
#   '도서관',
#   '만',
#   '가도',
#   '헉헉대다',
#   '눈앞',
#   '까맣다',
#   '세미',
#   '시체',
#   '이다',
#   '이제',
#   '다시',
#   '찌다',
#   '낮잠',
#   '별로',
#   '필요없다',
#   '체력',
#   '늘어나다',
#   '기분',
#   '이노'],
#  ['우노',
#   'ㅋㅋ',
#   '자댕',
#   '이의',
#   '존재',
#   '의미',
#   '이지',
#   '달리',
#   '뭔',
#   '데',
#   '거참',
#   '한국',
#   '남자',
#   '자의식',
#   '과잉',
#   '오다',
#   '이기',
#   '야'],
#  ['조국',
#   '수사',
#   '이제',
#   '막바지',
#   '기껏',
#   '해보다',
#   '와이프',
#   '표',
#   '장장',
#   '관련',
#   '의혹',
#   '전부',
#   '국민',
#   '을',
#   '위',
#   '검찰',
#   '개혁',
#   '이렇게',
#   '펴다',
#   '한당',
#   '언제',
#   '까지',
#   '용납',
#   '한당',
#   '반드시',
#   '청산',
#   '나라',
#   '발짝',
#   '이라도',
#   '앞',
#   '갈다',
#   '이제',
#   '적페당',
#   '끌리다',
#   '다니다',
#   '나약하다',
#   '민주당',
#   '심판'],
#  ['소고기', '짬뽕', '존나', '먹다', '보다'],
#  ['거', '나', '한경오', '제보', '댓글', '로', '대구', '개다', '이겠다'],
#  ['민아', '귀엽다'],
#  ['보지',
#   '돈',
#   '벌다',
#   '좋고꼬추',
#   '섹스',
#   '좋다',
#   '고서',
#   '로',
#   '윈윈',
#   '인데',
#   '게',
#   '왜',
#   '불법',
#   '이냐'],
#  ['로봉순', '젠', '신', '병자', '니까', '맘껏', '패', '라', '사람', '아니다'],
#  ['빍', 'ㅔ', '이츠', '공산당', '이다'],
#  ['한남', '말동무', '해주다', '심심하다'],
#  ['인의',
#   '수습',
#   '위원회',
#   '일제시대',
#   '신사참배',
#   '종교',
#   '적',
#   '행위',
#   '아니다',
#   '국민의례',
#   '라고',
#   '신사참배',
#   '합헌',
#   '것',
#   '같다',
#   '꼴',
#   '이네',
#   '인의',
#   '이름',
#   '영원하다',
#   '역사',
#   '수치',
#   '로',
#   '기록',
#   '되다'],
#  ['유민', '관인', '누구', '개그맨', '닮다', '않다'],
#  ['이상준', '황비홍', '댓', '냐'],
#  ['똥고', '들어가다', '꼬치', '먹다', '사람', '없다', '그렇다', '않다'],
#  ['보지', '민국', '에서', '뭘', '믿다', '보지', '믿다', '그렇다'],
#  ['막내',
#   '예뻣으',
#   '면',
#   '이런',
#   '일',
#   '없다',
#   '예쁘다',
#   '여자',
#   '저러다',
#   '한눈',
#   '팔리다',
#   '틈',
#   '조차',
#   '없다'],
#  ['그림', '체', '귀엽다', '하지만', '현실', '그렇다', '않다'],
#  ['출발', '이기', '야'],
#  ['저런', '것', '설명', '해주다', '모르다'],
#  ['우리', '에게는', '유모차', '부대', '있다'],
#  ['그렇게', '좋다', '따라가다', '제'],
#  ['엔', '두', '스타일', '엔', '엔', '엔', '엔', '엔', '엔', '두', '스타일'],
#  ['항상',
#   '패배',
#   '감',
#   '쩔다',
#   '그렇다',
#   '보다',
#   '상대',
#   '귀찮다',
#   '피하',
#   '것',
#   '을',
#   '지다',
#   '들이다',
#   '잘나다',
#   '이기다',
#   '알',
#   '고',
#   '좆',
#   '안되다',
#   '승리감',
#   '도취',
#   '감',
#   '빠지다',
#   '똥',
#   '을',
#   '기준',
#   '사람',
#   '똥',
#   '더럽다',
#   '피하',
#   '것',
#   '이지만',
#   '똥',
#   '지다',
#   '사람',
#   '에게',
#   '공포',
#   '가져오다',
#   '존재',
#   '라고',
#   '착각',
#   '것임'],
#  ['이렇다', '기사', '한국', '에서도', '곧', '나오다', '개슬람', '난민', '많아지다', '더', '만', 'ㅋㅋ'],
#  ['후팔', '가사', '저', '게뭐노'],
#  ['보석',
#   '같다',
#   '아끼다',
#   '꽁꽁',
#   '깜',
#   '추다',
#   '여자',
#   '돌맹',
#   '이냐',
#   '사람',
#   '이지',
#   '보석',
#   '이면',
#   '더',
#   '보여주다',
#   '자랑',
#   '하고',
#   '싶다',
#   '않다',
#   '왜',
#   '눈',
#   '만',
#   '보여주다'],
#  ['새끼',
#   '똥꼬',
#   '충',
#   '인거',
#   '같다',
#   '똥꼬',
#   '충',
#   '새끼',
#   '양성애자',
#   '존나',
#   '고',
#   '깝',
#   '게',
#   '보더',
#   '라',
#   '글',
#   '제목',
#   '부터가',
#   '성소수자',
#   '라고',
#   '대우',
#   '해주다',
#   '새끼',
#   '똥꼬',
#   '충',
#   '추정',
#   '되다'],
#  ['여자',
#   '사진',
#   '올라오다',
#   '따먹다',
#   '지랄',
#   '하고',
#   '여자',
#   '넘다',
#   '상폐',
#   '타령',
#   '하',
#   '일베',
#   '랑',
#   '뭐',
#   '다르다',
#   'ㅋㅋ'],
#  ['쌔끼들', '저', '손', '보다', '바짝', '쫄기', 'ㅋㅋ'],
#  ['여자', '자고로', '남자', '좃', '을', '물', '고', '살다', '배다'],
#  ['국산',
#   '남',
#   '특징',
#   '정확하다',
#   'ㅋㅋㅋㅋ',
#   '지',
#   '잘못',
#   '인정',
#   '안',
#   '다',
#   '일찍이',
#   '애비',
#   '뒤지다',
#   '놈',
#   '이라',
#   '상도',
#   '덕이',
#   '없다'],
#  ['기도', '뭐', '그렇게', '대단하다'],
#  ['안',
#   '만나다',
#   '분노',
#   '살인',
#   '한국',
#   '남자',
#   '로',
#   '태어나다',
#   '새끼',
#   '을',
#   '다',
#   '여섯',
#   '조각',
#   '찢다',
#   '죽이다',
#   '해결',
#   '되다',
#   '문',
#   '제노'],
#  ['관음', '자지', '인생', 'ㅆㅎㅌㅊ', '라서', '저', '거', '중', '살', '밖에', '못', '푸다', 'ㅋㅋㅋ'],
#  ['다문화',
#   '극혐',
#   '맞다',
#   '다인',
#   '종도',
#   '위험하다',
#   '데',
#   '어차피',
#   '일베',
#   '서',
#   '아무리',
#   '극혐씹극혐',
#   '소리',
#   '해봤다',
#   '변하다',
#   '없다',
#   '뭐',
#   '존나',
#   '뭉치다',
#   '시위',
#   '윗',
#   '대가리',
#   '들다',
#   '말랑하다',
#   '우리',
#   '일베충',
#   '그렇다',
#   '위인',
#   '얼마나',
#   '있다',
#   '그냥',
#   '글러',
#   '먹다',
#   '생각',
#   '하고',
#   '자기',
#   '살길',
#   '이나',
#   '찾다',
#   '되다'],
#  ['과학', '이고', '증거', '고', '뭐', '고', '다', '팔', '아', '먹다'],
#  ['백인',
#   '애',
#   '안',
#   '낳다',
#   '기독교',
#   '줄',
#   '거',
#   '고',
#   '이슬람',
#   '애',
#   '많이',
#   '낳다',
#   '불법이민',
#   '존나',
#   '가다',
#   '늘어나다'],
#  ['ㅇㅊㅇㅊㅇ', '베스트', '가라'],
#  ['문프발', '바이러스', '사다', 'ㅋㅋㅋ'],
#  ['저',
#   '기',
#   '다가',
#   '밤꽃',
#   '내다',
#   '나',
#   '액채',
#   '살며시',
#   '바르다',
#   '그렇다',
#   '내다',
#   '더욱',
#   'ㅅㅌㅊ',
#   '되다',
#   '이기',
#   '야'],
#  ['진짜',
#   '버러지',
#   '기생충',
#   '이다',
#   '사회',
#   '암',
#   '다인',
#   '권',
#   '복지',
#   '고',
#   '나발',
#   '이고',
#   '저런',
#   '것',
#   '삼청교육대',
#   '에서',
#   '정신',
#   '개조',
#   '필요하다'],
#  ['입', '개다', '숙대', '높다', '동대', '높다', '숙대', '에는', '꼴펨', '많다'],
#  ['아니다',
#   '시벌',
#   '터키',
#   '그나마',
#   '보수',
#   '적',
#   '마인드',
#   '때문',
#   '좋아하다',
#   '동성애자',
#   '저',
#   '정도',
#   '로',
#   '날뛰다',
#   '답',
#   '없다'],
#  ['대구', '븅', '신들'],
#  ['여대', '없애다', '여대', '왜', '있다', '이해', '안감'],
#  ['내', '스탈', '이야'],
#  ['거',
#   '생각',
#   '해보다',
#   '진짜',
#   '투신',
#   '자살',
#   '이다',
#   '생각',
#   '드노',
#   '강간',
#   '밀다',
#   '떨어트린거',
#   '아니다'],
#  ['가정',
#   '환경',
#   '도대체',
#   '어떻다',
#   '감형',
#   '없이',
#   '제대로',
#   '되다',
#   '처벌',
#   '을',
#   '불우하다',
#   '폭력',
#   '적',
#   '환경',
#   '에서',
#   '자라다',
#   '지',
#   '자식',
#   '때리다',
#   '죽이다',
#   '되다',
#   '법',
#   '따로',
#   '있다',
#   '임'],
#  ['조선족', '개새끼', '백린탄', '멸'],
#  ['다문화',
#   '그',
#   '종족',
#   '문화',
#   '존중',
#   '하고',
#   '지속',
#   '시키다',
#   '같이',
#   '행복하다',
#   '살다',
#   '이나',
#   '라는',
#   '짬뽕',
#   '이네',
#   '시부랄',
#   '거'],
#  ['아직',
#   '까진',
#   '불필요하다',
#   '여자',
#   '남자',
#   '속',
#   '에서',
#   '숨다',
#   '살다',
#   '또',
#   '소수자',
#   '만들다',
#   '지네',
#   '뭔',
#   '데',
#   '불편하다',
#   '그냥',
#   '숨다',
#   '살다'],
#  ['역시', '불의', '도시', '마', '갱', '상도', '싸나이', '뜨다', '급', '다', '아이'],
#  ['욱일기',
#   '침략',
#   '당',
#   '적도',
#   '없다',
#   '일본',
#   '에게',
#   '나라',
#   '팔',
#   '아',
#   '먹다',
#   '일본군',
#   '되어다',
#   '욱일기',
#   '같이',
#   '들다',
#   '아시아',
#   '정벌',
#   '을',
#   '같다',
#   '새끼',
#   '왜',
#   '저런',
#   '법',
#   '을',
#   '만들다',
#   '욱일기',
#   '언제',
#   '당하다',
#   '욱일기',
#   '고',
#   '일',
#   '본',
#   '군복',
#   '입다',
#   '가해',
#   '하고',
#   '다니다',
#   '족속',
#   '신분',
#   '세탁',
#   '하노'],
#  ['급식', '체', '분탕', '처리', '하고', '베다', '안되다'],
#  ['똥꼬', '충', '을', '권유', '시대', '까지', '오노'],
#  ['주적', '이라', '말다', '놈', '처럼', '어버버', 'ㅋㅋ'],
#  ['가깝다', '신안', '보내다', '세상', '그', '누구', '찾다'],
#  ['극',
#   '극',
#   '극',
#   '극',
#   '극',
#   '소수',
#   '위해',
#   '너무',
#   '많다',
#   '인력',
#   '예산',
#   '낭비',
#   '탁상',
#   '행정',
#   '끝판',
#   '이다'],
#  ['이기',
#   '뭐노',
#   '심심하다',
#   '때',
#   '마주치다',
#   '좆',
#   '한번',
#   '비',
#   '틀어주다',
#   '도망가다',
#   '생기다',
#   '수치심',
#   '걸음',
#   '정도',
#   '뛰다',
#   '헉헉',
#   '꿀꿀',
#   '재기',
#   '꼴',
#   '선하다',
#   'ㅋㅋ'],
#  ['난', '을', '지지', '인데', '솔직하다', '저', '늘다', '문제', '있다', '생각'],
#  ['시발', '일게이', '이제', '러브', '인', '아시아', '강제', '로', '찍다', '되다', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['개',
#   '소리',
#   '하노',
#   '시발',
#   '라마',
#   '조선족',
#   '중국인',
#   '인데',
#   '중국인',
#   '보다',
#   '뭔',
#   '개',
#   '소리',
#   '야',
#   '조선족',
#   '중국인',
#   '동일'],
#  ['아따',
#   '제목',
#   '만',
#   '보다',
#   '키부',
#   '니',
#   '놈',
#   '딱',
#   '조',
#   '아지',
#   '놐',
#   'ㅋㅋㅋㅋㅋㅋ',
#   '담',
#   '또',
#   '마주치다',
#   '후',
#   '장',
#   '우산',
#   '접다',
#   '피다',
#   '잊다',
#   '익'],
#  ['제발',
#   '성',
#   '관',
#   '관대하다',
#   '맙시',
#   '다',
#   '인류',
#   '미래',
#   '연관',
#   '되어다',
#   '있다',
#   '보다',
#   '성소수자',
#   '차별금지법',
#   '절대',
#   '반대',
#   '성',
#   '다수',
#   '역차별',
#   '당하다',
#   '법'],
#  ['일단', '후', '장', '뚫다', '고분'],
#  ['손정우',
#   '미국',
#   '보내다',
#   '않다',
#   '이렇다',
#   '공조',
#   '요청',
#   '하고',
#   'ㅋㅋㅋㅋ',
#   '결과',
#   '나오다',
#   '그것',
#   '꼭',
#   '기사',
#   '로',
#   '크게',
#   '크게',
#   '써주다',
#   '손동작',
#   '부터',
#   '해외',
#   '널리',
#   '널리',
#   '알려지다'],
#  ['어제',
#   '무',
#   '슨',
#   '날',
#   '이냐',
#   '어제',
#   '쓰다',
#   '국',
#   '가야',
#   '동',
#   '서머',
#   '근처',
#   '잔',
#   '가다',
#   '무슬림',
#   '새끼',
#   '모',
#   '여서',
#   '존나',
#   '가다',
#   '존나',
#   '빠개면',
#   '서',
#   '가다',
#   '알라',
#   '후',
#   '아크바르',
#   '지나가다',
#   '존나',
#   '야리다',
#   'ㅋ'],
#  ['남녀',
#   '헐벗',
#   '고',
#   '섹스',
#   '춤추다',
#   '퍼레이드',
#   '콘돔',
#   '나누다',
#   '바로',
#   '잡혀가다',
#   '동성연애',
#   '들이다',
#   '춤추다',
#   '항문',
#   '섹스',
#   '하',
#   '자고',
#   '콘돔',
#   '나누다',
#   '것',
#   '왜',
#   '가만두다'],
#  ['그러면', '좆국', '웜련들', '보지', '놀이터', '되다', '것', '이다'],
#  ['정상', '이냐', '헐다', '비정상', '을', '그냥', '다문화', '식', '인정', '해달라다', '아니다'],
#  ['에이즈', '주', '범', '똥꼬', '충', '인거', '이미', '통계', '로', '확인', '되어다'],
#  ['부랄',
#   '을',
#   '울리다',
#   '이기',
#   '야',
#   '와인',
#   '병',
#   '남충',
#   '틀니',
#   '나가다',
#   '재기',
#   '야',
#   '삼다',
#   '틀따라닦딲',
#   '틀딲딲',
#   '부롸',
#   '라라라',
#   '악',
#   '후두두',
#   '두둑'],
#  ['포괄', '적', '차별금지법', '을', '반대'],
#  ['년',
#   '후',
#   '인구',
#   '프로',
#   '차지',
#   '개슬람',
#   '자기',
#   '먹다',
#   '안',
#   '되다',
#   '고기',
#   '을',
#   '먹다',
#   '토종',
#   '인들',
#   '목',
#   '을',
#   '썰다',
#   '시작',
#   '국내',
#   '정치인',
#   '맞서다',
#   '즉각',
#   '적',
#   '개슬람',
#   '종교',
#   '바꿈',
#   '을',
#   '선언'],
#  ['사전', '오프모임', '필요', '없다'],
#  ['후팔', '호선', '이노'],
#  ['남자',
#   '고추',
#   '떼다',
#   '가시',
#   '나',
#   '들다',
#   '보다',
#   '가다',
#   '미치다',
#   '버리다',
#   '여기',
#   '서',
#   '여자친구',
#   '생기',
#   '면',
#   '동성애'],
#  ['맘충', '진상', '거지', '년', '애', '낳다', '것'],
#  ['장미', '칼', '미만', '잡'],
#  ['나다',
#   '이다',
#   '데',
#   '찬성',
#   'ㅎㅎ',
#   '신체',
#   '적',
#   '차이다',
#   '있다',
#   '때문',
#   '행정',
#   '이나',
#   '취사',
#   '병',
#   '처럼',
#   '군인',
#   '지원',
#   '쪽',
#   '으로라도',
#   '봄'],
#  ['개좆', '같다', '씨발', 'ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['단', '속', '안', '하', '나', '씨발'],
#  ['이미', '한남', '오다', '꾸다', '읍음'],
#  ['터키', '형제', '국가', '로', '생각', '나라', '좆', '보다', '아니다'],
#  ['전라도',
#   '세',
#   '끼',
#   '딱',
#   '보다',
#   '뭔가',
#   '혐오',
#   '가다',
#   '생기다',
#   '유전자',
#   '다른',
#   '종족',
#   '인',
#   '건',
#   '확실하다'],
#  ['여자', '이다', '신상', '공개', '안', '돼다', 'ㅋㅋㅋ'],
#  ['으', '니', '좆팔', 'ㅋㅋㅋㅋㅋ', '저게뭐놐', 'ㅋㅋㅋㅋ'],
#  ['인천',
#   '진짜',
#   '수도권',
#   '인데',
#   '제일',
#   '싸다',
#   '요즘',
#   '안산',
#   '부천',
#   '이딴',
#   '쓰레기',
#   '동네',
#   '다',
#   '오르다',
#   '인천',
#   '방어'],
#  ['예수',
#   '개',
#   '쓰레기',
#   '버러지',
#   '애미창렬',
#   '허다',
#   '벌',
#   '사기꾼',
#   '이지',
#   '예수',
#   '그',
#   '쓰레기',
#   '새끼',
#   'ㅎㅎ'],
#  ['경상도', '친구', '장점', '내', '존나', '지적', '하고', '꼽', '주', '고해', '다', '들어주다'],
#  ['어디가',
#   '서',
#   '지다',
#   '다리',
#   '짤',
#   '라',
#   '놓다',
#   '상해',
#   '당하다',
#   '참전',
#   '용다',
#   '해달라다',
#   '꼴',
#   '뭐',
#   '틀리다',
#   '군대',
#   '개인',
#   '적',
#   '인',
#   '일',
#   '탈',
#   '까지',
#   '법',
#   '어기다',
#   '지키다',
#   '되다',
#   '국방부'],
#  ['용돈', '받다', '해외여행', '다니다', '싶다', '남편', '버리다', '혼자', '다니다', '소린', 'ㅡㅡ'],
#  ['기초',
#   '학력',
#   '바닥',
#   '이다',
#   '페미',
#   '사상',
#   '이전',
#   '지식',
#   '올바르다',
#   '역사',
#   '로',
#   '가치관',
#   '을',
#   '아이',
#   '에게',
#   '가르치다',
#   '랏'],
#  ['오히려',
#   '지역',
#   '카페',
#   '매다',
#   '스텝',
#   '직',
#   '있다',
#   '아지',
#   '매',
#   '카페',
#   '카페',
#   '언급',
#   '더',
#   '조심스럽다',
#   '예민하다',
#   '노',
#   '인증',
#   '주작',
#   '써다',
#   'ㅈㅎ'],
#  ['우리',
#   '납치',
#   '왜',
#   '가다',
#   '싶다',
#   '사람',
#   '있다',
#   '거',
#   '라는',
#   '생각',
#   '을',
#   '싶다',
#   '중국',
#   '가다',
#   '넘다',
#   '갈수',
#   '있다',
#   '년',
#   '아',
#   '아구창',
#   '강냉이',
#   '다',
#   '털리다',
#   '패',
#   '고',
#   '싶다'],
#  ['나',
#   '같다',
#   '벌떡',
#   '일어서다',
#   '펄펄',
#   '끊다',
#   '된장찌개',
#   '애',
#   '새끼',
#   '머리',
#   '부어',
#   '버리다',
#   '애',
#   '밉다',
#   '년',
#   '얼굴',
#   '칼',
#   '로',
#   '난도질',
#   '존나'],
#  ['여',
#   '짓다',
#   '남자',
#   '로',
#   '살아오다',
#   '여군',
#   '이랑',
#   '같이',
#   '자고',
#   '같이',
#   '씻다',
#   '같이',
#   '싸다',
#   '이건',
#   '아니다',
#   '십',
#   '다',
#   '그리고',
#   '여군',
#   '려면',
#   '시험',
#   '다시',
#   '보다',
#   '아니다',
#   '삼성',
#   '붙다',
#   '시험',
#   '안보',
#   '고',
#   '들어가다',
#   '꼴'],
#  ['아',
#   '진심',
#   '보다',
#   '조팔',
#   '육성',
#   '욕',
#   '진짜',
#   '좆국',
#   '갈다',
#   '잦다',
#   '들다',
#   '못',
#   '생기다',
#   '새끼',
#   '그',
#   '중',
#   '에서도',
#   'ㅆㅆㅎㅌㅊ',
#   '노',
#   '오다',
#   '후팔',
#   '어떻다',
#   '저렇게',
#   '생기다'],
#  ['이렇다', '개독', '새끼', '을', '좋다', '빨', '아대', '통베', '수준', 'ㄷ'],
#  ['근데', '고경표', '군대', '간다', '고', '하차', '거', '아니다'],
#  ['죶',
#   '나',
#   '역겹다',
#   '산업',
#   '폐기물',
#   '보다',
#   '못',
#   '새끼',
#   'ㄷ',
#   '오유충',
#   '등',
#   '일베',
#   '서다',
#   '민주화',
#   '주다'],
#  ['고딩', '때', '공부', '만', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['사회',
#   '분열',
#   '남녀',
#   '갈등',
#   '심각하다',
#   '정치인',
#   '이라는',
#   '작자',
#   '거기',
#   '숟가락',
#   '이나',
#   '얹다',
#   '들다',
#   '한심하다'],
#  ['근대',
#   '시',
#   '전두환',
#   '각하',
#   '미우다',
#   '그렇다',
#   '아니다',
#   '진심',
#   '머',
#   '중',
#   '이를',
#   '존경',
#   '존나',
#   '궁금하다'],
#  ['숫', '비둘기', '워', '치다', 'ㅋㅋㅋ'],
#  ['알다', '없다', '우울', '감', '적절하다', 'ㅋㄱㅋㅋ'],
#  ['아니다', '노', '짱', '염라대왕', '시', '거들다', '하라', '보지', '나', '따르다'],
#  ['신천지',
#   '사이비',
#   '사회',
#   '적',
#   '암',
#   '같다',
#   '집단',
#   '무지개',
#   '사회',
#   '적',
#   '암',
#   '같다',
#   '존재',
#   '개인',
#   '자유',
#   '존중',
#   '받다',
#   '마땅하다',
#   '그게',
#   '정상',
#   '아니다',
#   '거',
#   '다',
#   '알',
#   '나',
#   '암',
#   '처럼',
#   '알다'],
#  ['인류사', '최대', '사기', '종교', '라고', '누가', '얘기', '하'],
#  ['잘알다', '안', '사다'],
#  ['필',
#   '리피',
#   '노',
#   '구라',
#   '종특',
#   '이냐',
#   '시발',
#   '미카',
#   '슈스케',
#   '나오다',
#   '구라',
#   '존나',
#   '치다',
#   '하여간',
#   '동남아',
#   '새끼'],
#  ['워마드메', '갈다', '페미니즘', '을', '빙자', '테러', '집단'],
#  ['아니다', '그', '전', '범죄', '저지르다', '누군데', 'ㅋㅋ', '뇌', '장식', '임', 'ㅋㅋㅋㅋㅋㅋ'],
#  ['점마', '아직', '재기', '안햇노'],
#  ['저',
#   '년',
#   '지다',
#   '믿음',
#   '목사',
#   '친목',
#   '을',
#   '위해',
#   '서',
#   '저',
#   '지랄',
#   '까지',
#   '한다는',
#   '게',
#   '본인',
#   '스스로',
#   '자괴',
#   '감',
#   '안드',
#   '나',
#   '자존감',
#   '이라는',
#   '게',
#   '없다',
#   '듯',
#   'ㅋ',
#   '예수',
#   '없다',
#   '팩',
#   '틀다',
#   '아니다',
#   '아니다',
#   '눈가',
#   '리',
#   '고',
#   '성경',
#   '소설',
#   '치다',
#   '읽다',
#   'ㅋ'],
#  ['글좀', '잘쓰다'],
#  ['ㅇㅈ',
#   '짱구',
#   '드래곤볼',
#   '심지어',
#   '지',
#   '금도',
#   '넷플',
#   '에서',
#   '애니',
#   '보다',
#   '반일',
#   '절',
#   '라도',
#   '늘다',
#   '자살',
#   'ㄱ'],
#  ['조선족',
#   '짱개',
#   '인데',
#   '둘',
#   '을',
#   '구',
#   '분할필요',
#   '없다',
#   '즉',
#   '여기',
#   '엔',
#   '짱개',
#   '졸라',
#   '많다',
#   '주기',
#   '적',
#   '시간',
#   '단위',
#   '로',
#   '짱개',
#   '깔다',
#   '글',
#   '올라오다',
#   '필요',
#   '잇다',
#   '소리',
#   '임'],
#  ['저',
#   '거',
#   '목숨',
#   '걸다',
#   '말고',
#   '약사',
#   '면',
#   '다른',
#   '먹거리',
#   '찾다',
#   '모름',
#   '미국',
#   '에서는',
#   '이미',
#   '약사',
#   '일',
#   '기계',
#   '있다',
#   '미래',
#   '생각',
#   '보다',
#   '멀다',
#   '않다'],
#  ['남충', '새끼', '그냥', '좆질', '살다', '같다'],
#  ['이렇다',
#   '씨발',
#   '딱',
#   '거',
#   '랑',
#   '똑같다',
#   '스토리',
#   '야동',
#   '이나',
#   '망',
#   '야애니',
#   '추천',
#   '받다',
#   '씨발',
#   '빨리',
#   '고추',
#   '섯다'],
#  ['새끼', 'ㄹㅇ', '좆', '돼다', '네', '징역', '년', '맞다', 'ㅋㅋㅋㅋㅋㅋㅋ'],
#  ['연봉', '수십', '억', '을', '버리다'],
#  ['대', '구', '게이', '일베', '글', '쓰다', '마르다', '타고', '우한', '폐렴', '전파', '되다'],
#  ['돈', '많다', '안', '밝히다', '고자', '로', '의심', '그러므로', '빌다', '극히', '정상', 'ㅋㅋㅋ'],
#  ['유튜브',
#   '짱깨',
#   '라',
#   '쓰다',
#   '칼삭',
#   '되다',
#   '존나',
#   '웃기',
#   '지',
#   '않다',
#   '유튜브',
#   '왜',
#   '이렇게',
#   '까지',
#   '건지다',
#   '모르다',
#   '미국',
#   '기업',
#   '이면',
#   '서'],
#  ['문', '병신', '페미', '짝짝', '꿍', '나라', '망하다', '징조', '노', 'ㅋㅋ'],
#  ['이쯤', '에서', '팩트', '체킹'],
#  ['ㅎㄹㅆ', 'ㅇㄷㅃ'],
#  ['운전면허', '없다', '운전면허', '따다', '지원', '해주다', '내', '몸', '바치다'],
#  ['꼭',
#   '저러다',
#   '버리다',
#   '년',
#   '보다',
#   '뚱뚱하다',
#   '맘충',
#   '더',
#   '라',
#   '돈까스',
#   '시키다',
#   '먹다',
#   '적다',
#   '나오다',
#   '따지다',
#   '년'],
#  ['산소', '아깝다', '빨리', '뛰어내리다'],
#  ['남충',
#   '피',
#   '싸개',
#   '같이',
#   '쓰다',
#   '어떻다',
#   '되다',
#   '피남',
#   '싸다',
#   '충',
#   '개',
#   '이렇게',
#   '어떻다',
#   '되다'],
#  ['집사', '님', '들다', '덩치', '함워마드', '돼지', '년', '한테', '안', '꾸다', '림'],
#  ['돼다',
#   '두다',
#   '슈카형',
#   '한테',
#   '배우다',
#   '오다',
#   '진짜',
#   '세대',
#   '한테',
#   '어떻다',
#   '정치',
#   '밥',
#   '먹다',
#   '인간',
#   '보다',
#   '일개',
#   '유튜버',
#   '더',
#   '뛰어나다',
#   '보이',
#   '네',
#   'ㅋㅋㅋㅋㅋㅋ'],
#  ['더럽다',
#   '똥',
#   '꺼',
#   '충',
#   '새끼',
#   '아가리',
#   '갈다',
#   '좆',
#   '물',
#   '고',
#   '후',
#   '장',
#   '엔',
#   '철근',
#   '빵',
#   '뒈지다'],
#  ['고', '왕릉', '디시', '고정닉', '야', '같잩', '엘리트', '새끼', '아'],
#  ['중국', '살', '면', '심심하다', '않다'],
#  ['말', '장난', '자빠지다', 'ㅋㅋㅋㅋ', '수준', '하고는'],
#  ['구상권', '무조', '권', '청구'],
#  ['짱깨',
#   '북한',
#   '한국',
#   '넘다',
#   '들다',
#   '기생충',
#   '짓',
#   '만',
#   '고르다',
#   '서하',
#   '족보',
#   '없다',
#   '개',
#   '쓰레기',
#   '구더기',
#   '만도',
#   '못',
#   '좆족',
#   '새끼',
#   '씨발',
#   '조선족',
#   '전용',
#   '세스코',
#   '만들다',
#   '박멸',
#   '되다',
#   '씨발',
#   '사기',
#   '살인',
#   '협박',
#   '폭행',
#   '등등',
#   '종족',
#   '자체',
#   '불법',
#   '유지',
#   '되다',
#   '개',
#   '쓰레기',
#   '인종',
#   '새끼',
#   '어디서',
#   '깝',
#   '치노'],
#  ['아직도', '처', '놀다', '가다', '보다', '속', '천', '불', '나다'],
#  ['적당하다',
#   '지다',
#   '혼자',
#   '코르셋',
#   '조여',
#   '이미지',
#   '메이킹',
#   '충분하다',
#   '가능하다',
#   '걸',
#   '욕심',
#   '내다',
#   '자꾸',
#   '한국',
#   '여자',
#   '걸다',
#   '넘어지다',
#   '비호감'],
#  ['안이',
#   '저렇게',
#   '나오다',
#   '문',
#   '똥꼬',
#   '충',
#   '을',
#   '오히려',
#   '다음',
#   '번',
#   '총선',
#   '비례대표',
#   '로',
#   '만들다',
#   '베충',
#   '들이다',
#   '원하다',
#   '반',
#   '동성애',
#   '정책',
#   '절대',
#   '내놓다',
#   '않다'],
#  ['보릉내', '진동'],
#  ['삼일한', '정신', '알라', '에게도', '있다'],
#  ['물리학자', '장애인', '명', '이나', '되다'],
#  ['게', '왜', '차금법', '이랑', '연결', '되다', '이해', '안되다', '저', '뿐', '인가요'],
#  ['나이', '먹다', '자식', '이랑', '보다', '개', '꾸다'],
#  ['외상',
#   '후',
#   '스트레스',
#   '장애',
#   '충격',
#   '받다',
#   '일이',
#   '있다',
#   '그',
#   '뒤',
#   '로',
#   '그',
#   '비슷하다',
#   '것',
#   '만',
#   '보다',
#   '머릿속',
#   '경',
#   '고등',
#   '군무',
#   '빼액빼액',
#   '울',
#   '리기',
#   '때문',
#   '정상',
#   '적',
#   '이고',
#   '여유',
#   '로운',
#   '사고',
#   '못',
#   '되다',
#   '심리',
#   '상태',
#   '말'],
#  ['그렇다',
#   '일베',
#   '에서',
#   '틀',
#   '딱',
#   '드립',
#   '이나',
#   '여론조작',
#   '허다',
#   '있다',
#   '조선족',
#   '새끼',
#   '역대',
#   '가장',
#   '최악',
#   '이지'],
#  ['이래서', '남경', '뽑다', '안', '돼다'],
#  ['서현', '응원'],
#  ['병신',
#   '많다',
#   '자지',
#   '꼴리다',
#   '때',
#   '편의점',
#   '가다',
#   '박카스',
#   '병',
#   '사',
#   '고',
#   '동네',
#   '어슬렁거리다',
#   '박카스',
#   '아줌마',
#   '딱',
#   '보고',
#   '눈치',
#   '끄다',
#   '함',
#   '대',
#   '줌',
#   '대신',
#   '박카스',
#   '상납',
#   '되다'],
#  ['우리나라',
#   '에는',
#   '비정상회담',
#   '에서',
#   '겨우',
#   '중국공산당',
#   '아니다',
#   '아예',
#   '중공군',
#   '복무',
#   '자랑',
#   '스럽게',
#   '떠벌리다',
#   '새끼',
#   '있다',
#   '그',
#   '인간',
#   '이제',
#   '미국',
#   '못',
#   '가다',
#   'ㅋㅋㅋ'],
#  ['미군', '오빠', '그렇다', '좆', '분', '짜다', '고', '기', '방패', '남', '아', '좆'],
#  ['근데',
#   '세월호',
#   '드립',
#   '진짜',
#   '로',
#   '웃기다',
#   'ㅋㅋㅋ',
#   '남발',
#   '저',
#   '게',
#   '웃기',
#   '면',
#   '진짜',
#   '사회생활',
#   '못',
#   '정도',
#   '일',
#   '탠데'],
#  ['시',
#   '팔',
#   '새끼',
#   '말',
#   '뽄',
#   '새',
#   '보이',
#   '밥',
#   '빌어',
#   '쳐묵겄다',
#   '정권',
#   '바뀌다',
#   '저',
#   '거세',
#   '상',
#   '인',
#   '줄',
#   '아',
#   '네'],
#  ['ㅋㅋㅋㅋㅋㅋ', '맞다', '말', '인데', '왜', '부들', '거리', '놐', 'ㅋㅋ'],
#  ['심지어', '여성', '분', '더', '나이', '많다', '보이다'],
#  ['신천지', '계획', '다', '있다', '동성애자', '이랑', '연합', '이런', '식', '몰다', '가보다', 'ㅋㅋ'],
#  ['너', '그', '나잘하다'],
#  ['트랜스',
#   '가보다',
#   '년',
#   '을',
#   '알다',
#   '나',
#   '쓸다',
#   '기사',
#   '그',
#   '리도',
#   '없다',
#   '아',
#   '경향',
#   '이구나'],
#  ['답',
#   '을',
#   '알다',
#   '줌',
#   '공',
#   '수',
#   '처',
#   '중국',
#   '북한',
#   '에만',
#   '있다',
#   '저',
#   '거',
#   '보다',
#   '딱',
#   '알다',
#   'ㅋㅋㅋㅋ'],
#  ['깨닫다', '공부', '아니다'],
#  ['씨발', '이나라', '땅값', '알', '고', '말', '나다', '난민', '신청', '하고', '집', '받다', '싶다'],
#  ['코로나',
#   '팬데믹',
#   '황폐',
#   '화',
#   '되다',
#   '세상',
#   '을',
#   '예',
#   '수',
#   '그리스도',
#   '생명',
#   '복음',
#   '녹색',
#   '화하다'],
#  ['순수하다', '풀', '스윙'],
#  ['남유럽',
#   '중유럽',
#   '동유럽',
#   '다',
#   '난민',
#   '받다',
#   '죽다',
#   '서유럽',
#   '으로만',
#   '가다',
#   '보다',
#   '도둑',
#   '놈',
#   '새끼',
#   '들이다'],
#  ['보아', '대종교', '다', '건드리다', '듯', '지다', '들이다', '이다', '아', '나', '봄'],
#  ['게이',
#   '좆',
#   '같다',
#   '레즈',
#   '좆',
#   '같다',
#   '동성애',
#   '씨발',
#   '년놈',
#   '옛날',
#   '처럼',
#   '아우슈비츠',
#   '가스실',
#   '싸',
#   '그리다',
#   '모으다',
#   '독가스',
#   '살포',
#   '애',
#   '밉다',
#   '애비',
#   '보다',
#   '앞',
#   '에서',
#   '고통스럽다',
#   '잔인하다',
#   '죽이다',
#   '되다'],
#  ['무조건', '이해', '하', '라고', '폭력', '이지'],
#  ['노친', '네', '들다', '잡다', '죽이다', '애국'],
#  ['젠', '신병', '정신병', '이노'],
#  ['다문화', '걱정', '단결', '성하다', '쓸다', '버리다'],
#  ['스시', '남', '패', '고', '다니다', '개웃', '챙', '이노', 'ㅋㅋㅋㅋ'],
#  ['백',
#   '신',
#   '개발',
#   '박차',
#   '가하다',
#   '좋다',
#   '소',
#   '식이',
#   '네',
#   '요',
#   '하루속히',
#   '코로나',
#   '위협',
#   '부터',
#   '안전하다',
#   '그날',
#   '오다',
#   '기대하다',
#   '대한민국',
#   '홧팅입니',
#   '다'],
#  ['필리핀',
#   '여자',
#   '랑',
#   '결혼',
#   '남자',
#   '얼마나',
#   '한국',
#   '여자',
#   '에게',
#   '인기',
#   '없다',
#   '흑인',
#   '이랑',
#   '결혼',
#   '한심하다',
#   '애',
#   '자동',
#   '검둥이'],
#  ['그래서',
#   '신도시',
#   '맘충년',
#   '유독',
#   '진성',
#   '맘충년',
#   '인데',
#   '그',
#   '중',
#   '에서도',
#   '맘충',
#   '대장',
#   '동탄',
#   '맘년',
#   '들이다'],
#  ['라도', '쌍', '도르다', '부르다', '함'],
#  ['우린', '전라도', '있다', '튀기다', '새끼', '한테', '질', '일', '없다'],
#  ['그렇다',
#   '청소년',
#   '뭐',
#   '불쾌하다',
#   '없다',
#   '신가',
#   '이중',
#   '잣',
#   '대',
#   '꼬',
#   '라지',
#   '만하',
#   '다',
#   'ㅋㅋㅋㅋㅋ',
#   '실체',
#   '없다',
#   '헛짓',
#   '돈',
#   '주다',
#   '관심',
#   '주다',
#   '세금',
#   '줄줄',
#   '세지'],
#  ['작다',
#   '물방울',
#   '하나',
#   '하나',
#   '모이다',
#   '푸른',
#   '강물',
#   '을',
#   '이루다',
#   '모래',
#   '알',
#   '알',
#   '모이다',
#   '은빛',
#   '사막',
#   '을',
#   '이루다',
#   '별',
#   '하나',
#   '하나',
#   '모이다',
#   '은하수',
#   '이루다',
#   '한국',
#   '교회',
#   '연합',
#   '기관',
#   '하나',
#   '되어다',
#   '원',
#   '메세지',
#   '원',
#   '리더쉽',
#   '힘',
#   '을',
#   '모으다',
#   '부흥',
#   '전성기',
#   '맞이',
#   '길',
#   '기',
#   '도합',
#   '니',
#   '다'],
#  ['게이', '나치', '새끼'],
#  ['려자',
#   '례쁘',
#   '게',
#   '안',
#   '꾸미다',
#   '지',
#   '테',
#   '자다',
#   '보이다',
#   '노력',
#   '안',
#   '국산',
#   '남다',
#   '쥐좆',
#   '쪼그라들다',
#   '이기',
#   '야'],
#  ['뭐', '미개하다', 'ㅋㅋㅋ', '서울', '말', '써다', '안', '미개하다', 'ㅋㅋ'],
#  ['치다', '맞다', '말', 'ㅋ'],
#  ['탈북자',
#   '새끼',
#   '몸',
#   '만',
#   '자본주의',
#   '따르다',
#   '나오다',
#   '정신',
#   '수령',
#   '님',
#   '아바이',
#   '이딴',
#   '식',
#   '일',
#   '걸',
#   'ㅋㅋㅋㅋㅋㅋㅋ'],
#  ['저', '게', '무슨', '난민', '이야', 'ㅋㅋㅋ', '밀', '입국', '자지'],
#  ['우리', '동방예의지국', '이다', '짱깨', '노예'],
#  ['서울시장',
#   '후보',
#   '간',
#   '경쟁',
#   '에서',
#   '형오',
#   '발언',
#   '문',
#   '제',
#   '그',
#   '누구',
#   '나쁘다',
#   '또는',
#   '형오',
#   '스럽다',
#   '얘기',
#   '한적',
#   '없다',
#   '같다',
#   '다만',
#   '그',
#   '만의',
#   '축제',
#   '도심',
#   '복판',
#   '에서',
#   '하',
#   '는걸',
#   '안',
#   '보다',
#   '권리',
#   '있다',
#   '얘기',
#   '뿐',
#   '무조건',
#   '남탓',
#   '으로만',
#   '말다'],
#  ['목사', '란', '새끼', '인간', '아니다'],
#  ['맞다',
#   '니',
#   '말',
#   '다',
#   '받다',
#   '웜년',
#   '끼리',
#   '꾸준하다',
#   '논의',
#   '하고',
#   '상의',
#   '새',
#   '논제',
#   '라고',
#   '생각',
#   '또',
#   '것',
#   '웜년들',
#   '사이',
#   '자연',
#   '스럽게',
#   '녹다',
#   '들다',
#   '하노',
#   '의미',
#   '없다',
#   '플로우',
#   '흘리다',
#   '보내다',
#   '니',
#   '말',
#   '네',
#   '가지',
#   '주제',
#   '플로우',
#   '로',
#   '자리',
#   '잡다',
#   '하노',
#   '더',
#   '생각',
#   '하고',
#   '나다',
#   '글',
#   '써다',
#   '보다'],
#  ['찜', '방이', '익숙하다', '좋다', '제', '오'],
#  ['교촌치킨',
#   '콤보',
#   '말고',
#   '마리',
#   '포장',
#   '사오다',
#   '만오천원',
#   '밖에',
#   '안',
#   '저건',
#   '비주',
#   '얼',
#   '만',
#   '보다',
#   '개',
#   'ㅎㅌㅊ',
#   '치킨',
#   '같다',
#   '특이하다',
#   '메뉴',
#   '아니다',
#   '저런',
#   '평범하다',
#   '비싸다',
#   '먹다',
#   '바',
#   '양',
#   '적다',
#   '보이다',
#   '교촌',
#   '먹음'],
#  ['망나니', '지만', '중국', '을', '제대로', '죽이다', '인정'],
#  ['틀', '무질', '하', '새끼', '평균', '나이', '저', '거임', '존나', '황당하다', '임'],
#  ['혐오',
#   '스럽게',
#   '보기',
#   '좋다',
#   '간',
#   '동성애자',
#   '가능하다',
#   '다',
#   '살',
#   '처분',
#   '공익',
#   '차원',
#   '에서',
#   '바람직하다',
#   '대안',
#   '임'],
#  ['ㅋㅋㅋㅋㅋㅋㅋ',
#   '니미',
#   '시발',
#   '동남아',
#   '새끼',
#   '왜',
#   '비례대표',
#   '로',
#   '꼽',
#   '아',
#   '주다',
#   '이해',
#   '가안',
#   '가다',
#   '씨발',
#   '진짜'],
#  ['토크',
#   '온',
#   '에서',
#   '페미',
#   '년',
#   '이랑',
#   '배틀',
#   '뜰랬',
#   '늘다',
#   '토크',
#   '온',
#   '접속',
#   '하고',
#   '펑',
#   '터지다',
#   '게',
#   '토크',
#   '온',
#   '무슨',
#   '공격',
#   '던데'],
#  ['탈북자', '에서도', '모태', '좌좀', '있다', '모태', '우좀', '있다', '법', 'ㅋㅋㅋ'],
#  ['게이',
#   '아',
#   '올바르다',
#   '야동',
#   '보다',
#   '동성애자',
#   '쪽',
#   '보지',
#   '말고',
#   '이성애자',
#   '드립',
#   '야동',
#   '만',
#   '보다',
#   '아',
#   '차다',
#   '종교',
#   '게이',
#   '보다',
#   '무조건',
#   '회개',
#   '하',
#   '거나',
#   '고해성사',
#   '꼭',
#   '해',
#   '라'],
#  ['적',
#   '화',
#   '다',
#   '된거',
#   '냐',
#   'ㅋㅋㅋㅋㅋㅋ',
#   '기',
#   '차다',
#   '빨갱이',
#   '많다',
#   '많다',
#   '가보다',
#   '이나라'],
#  ['한국', '브라질', '대구', '한국', '멕시코', '전라도', '한국', '인도', '부산'],
#  ['후팔', '시력', '재다', '뿟노', '쇼린', '사진', '내놓다', '이기'],
#  ['근데',
#   '피쟈',
#   '게이',
#   '그',
#   '글',
#   '이후',
#   '로',
#   '댓글',
#   '안달',
#   '고',
#   '글',
#   '안',
#   '쓰다',
#   '잠수',
#   '타다',
#   '같다'],
#  ['김치',
#   '녀',
#   '능력',
#   '있다',
#   '여자',
#   '라',
#   '좆',
#   '거지',
#   '고추',
#   '작다',
#   '한남',
#   '안',
#   '만나다',
#   '이기',
#   '야'],
#  ['힝', '불쌍하다'],
#  ['동성애', '법적', '허용', '을', '절대', '반대', '다'],
#  ['교회', '세금', '받다', '전형', '적', '인', '집단', '광기', '판매', '기업', '인데'],
#  ['아니다',
#   '근데',
#   '원래',
#   '군대',
#   '한국',
#   '국적',
#   '이어도',
#   '외국인',
#   '외모',
#   '면',
#   '면제',
#   '시키다',
#   '않다'],
#  ['일베',
#   '왜',
#   '짜른거',
#   '니',
#   '형평성',
#   '안',
#   '맞다',
#   '당연하다',
#   '남혐하',
#   '여성시대',
#   '메',
#   '갈다',
#   '인간',
#   '목',
#   '을',
#   '치다',
#   '정당하다',
#   '사유',
#   '남녀',
#   '바꾸다',
#   '똑같다',
#   '왜',
#   '여자',
#   '따르다',
#   '안되다',
#   '대체',
#   '왜'],
#  ['자지',
#   '사이즈',
#   '부랄',
#   '부터',
#   '재놐',
#   'ㅋㅋㅋㅋㅋㅋ',
#   '당연하다',
#   '고추밑둥',
#   '부터',
#   '재야',
#   '지',
#   '왜',
#   '부랄',
#   '을',
#   '포함',
#   '하',
#   '놐',
#   'ㅋㅋㅋㅋㅋㅋ',
#   '이래서',
#   '남자',
#   '멍청하다'],
#  ['살다', '그리고', '틀', '딱', '관광객', '아니다', '공원', '소유', '자임'],
#  ['보지', '자리', '세월호', '리본', '들어가다', '진정하다', '페미니즘', '빨다', '스임', '큨', 'ㅋ'],
#  ['솔직하다', '일베', '모', '쏠다', '들다', '워마드년들', '대다', '보빨', '놈', '대부분', '임', 'ㅇㅈ'],
#  ['여자라서', '부럽다'],
#  ['우리',
#   '원',
#   '탈북',
#   '새끼',
#   '아가리',
#   '에서',
#   '나오다',
#   '소리',
#   '냐',
#   '저',
#   '게',
#   '그렇게',
#   '좋다',
#   '왜',
#   '탈북',
#   '함'],
#  ['애',
#   '키우다',
#   '입장',
#   '에서',
#   'ㅎㅎ',
#   '개',
#   '키우다',
#   '입장',
#   '에서',
#   '로',
#   '들리다',
#   '맘충',
#   '카페',
#   '다',
#   '뒤지다',
#   '가다',
#   '횡포',
#   '다',
#   '콩밥',
#   '먹이다',
#   '야하다'],
#  ['메갈페',
#   'ㅇ',
#   '미부',
#   '하루빨리',
#   '없애다',
#   '조이',
#   '상',
#   '비싸다',
#   '세금',
#   '받다',
#   '처',
#   '먹다',
#   '쓸데없다',
#   '곳',
#   '돈',
#   '낭비하다',
#   '곳'],
#  ['고민',
#   '되다',
#   '정의',
#   '든든하다',
#   '뒷',
#   '빽',
#   '삶다',
#   '대가리',
#   '이라',
#   '잖다',
#   '그렇다',
#   '그',
#   '나물',
#   '그',
#   '밥',
#   '인데',
#   '개',
#   '나',
#   '소나',
#   '미치다',
#   '총선',
#   '제대로',
#   '찍다',
#   '자유',
#   '지키다'],
#  ['가다', '고소하다', '고소', '안', '당하다', '조심하다', '불매'],
#  ['현명하다',
#   '거',
#   '꼭',
#   '여자',
#   '한테',
#   '만',
#   '쓰다',
#   '덥다',
#   '특히',
#   '주부',
#   '개념',
#   '녀',
#   '탈',
#   '씌우다',
#   '입문',
#   '용',
#   '표현',
#   '인',
#   '느낌',
#   '이다',
#   '자지',
#   '한테',
#   '현명하다',
#   '굴레',
#   '씌우다',
#   '싶다',
#   '이기',
#   '야'],
#  ['진압당',
#   '하고',
#   '치다',
#   '발리',
#   '면',
#   '홍',
#   '통일체',
#   '라며',
#   '양비론',
#   '해',
#   '버리다',
#   '나르다',
#   '버리다',
#   '졸렬하다',
#   '홍어',
#   '새끼',
#   'ㅋㅋ'],
#  ['남자', '페미', '일단', '한남', '이니', '선', '재기'],
#  ['후팔',
#   '자다',
#   '웜',
#   '켜다',
#   '보고',
#   '스크랩',
#   '나름',
#   '메',
#   '갈다',
#   '때',
#   '부터',
#   '달리다',
#   '쉬익쉬익',
#   '소중하다',
#   '자료',
#   '고맙다',
#   '니야'],
#  ['오다',
#   '교도소',
#   '아니다',
#   '저런',
#   '어처구니',
#   '없다',
#   '집단',
#   '생활',
#   '하고',
#   '차다',
#   '불쌍타',
#   '보내다',
#   '부모',
#   '이나',
#   '있다',
#   '학생',
#   '이나',
#   '시설',
#   '저',
#   '모양',
#   '인데',
#   '식단',
#   '안',
#   '보다',
#   '알다',
#   '불쌍하다',
#   'ㅜㅜ'],
#  ['이제',
#   '겨우',
#   '결혼',
#   '노총각',
#   '인데',
#   '만약',
#   '꽃뱀',
#   '면',
#   '진짜',
#   '슬프다',
#   '진짜',
#   '라면',
#   '뭐',
#   '망하다'],
#  ['디지다', '너', '좋다', '주님', '곁', '치다'],
#  ['북', '딱', '딱', '기분', '딱좋다', '타다', '망', '해보다', '이기', '야'],
#  ['미국',
#   '교통사고',
#   '나',
#   '단',
#   '순',
#   '폭력',
#   '얼굴',
#   '깔다',
#   '범죄자',
#   '인격',
#   '무시',
#   '감안',
#   '하고',
#   '범죄',
#   '저지르다',
#   '겨'],
#  ['자릉내', '비', '질염', '냄새', '향기', '수준', '이다'],
#  ['한국',
#   '짱깨',
#   '처럼',
#   '문화',
#   '대혁명',
#   '되다',
#   '통',
#   '위병',
#   '결성',
#   '좆',
#   '새끼',
#   '숙청',
#   '축출',
#   '제거',
#   '척살',
#   '을',
#   '위',
#   '혁명',
#   '일으키다'],
#  ['중동', '새끼', '냄새', '때문', '에라도', '안되다', '존나', '냄새', '암내', '시발'],
#  ['ㅎㅎㅎㅎ',
#   '뭐',
#   '어쩌라고',
#   '트젠',
#   '여혐',
#   '오지',
#   '게',
#   '여자',
#   '에게',
#   '연',
#   '대하',
#   '라는',
#   '심보',
#   '뭐임',
#   'ㅋㅋㅋㅋㅋㅋㅋ',
#   '연대',
#   '맡기다',
#   '한남',
#   '아',
#   '니',
#   '여혐',
#   '이나',
#   '소수자',
#   '혐오',
#   '주',
#   '계층',
#   '남이면',
#   '서',
#   '지다',
#   '들이다',
#   '안',
#   '여자',
#   '왜',
#   '안해',
#   '빼',
#   '애액',
#   '앵',
#   '가다',
#   '울다'],
#  ['나', '뉴질랜드', '살다'],
#  ['서로',
#   '인정',
#   '하고',
#   '선',
#   '을',
#   '그으',
#   '면',
#   '되다',
#   '문제',
#   '왜',
#   '니',
#   '끼리',
#   '지적',
#   '하고',
#   '니',
#   '잘나다',
#   '내',
#   '잘나다',
#   '싸우다',
#   '있다',
#   '내',
#   '남국',
#   '면',
#   '거',
#   '보고',
#   '번은',
#   '사정',
#   '이기'],
#  ['요즘', '이민', '수속', '을', '구청', '에서', 'ㅋㅋ'],
#  ['판년', '멍청하다', '저러다', '존나', '열', '내다', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['두번째', '내', '스탈', '얌', 'ㅎㅎ'],
#  ['빽', '시리즈', '유행', '이유', '한남'],
#  ['차',
#   '세계대전',
#   '이슬람',
#   '쪽',
#   '에서',
#   '일어난다',
#   '이슬람',
#   '쪽',
#   '에서',
#   '핵무기',
#   '먼저',
#   '사용',
#   '임',
#   '영화로',
#   '몇개',
#   '나오다',
#   '이미',
#   '터지다',
#   '시',
#   '간문제'],
#  ['ㄴㄴ',
#   '경찰',
#   '죄다',
#   '보지',
#   '년',
#   '로',
#   '바꾸다',
#   '치안',
#   '좆',
#   '돼다',
#   '보다',
#   '시발',
#   '년',
#   '정신차리다'],
#  ['대구', 'ㄷㄷㄷ'],
#  ['시발',
#   '탈',
#   '코르셋',
#   '지랄',
#   '하고',
#   '있다',
#   '들이다',
#   '선택',
#   '못',
#   '받다',
#   '스스로',
#   '위안',
#   '삼고',
#   '뭔',
#   '탈',
#   '코르셋',
#   'ㅋㅋㅋ',
#   '존나',
#   '못',
#   '생기다',
#   '네',
#   '진짜',
#   'ㅋㅋㅋㅋㅋㅋㅋㄱ',
#   '고르다',
#   '타',
#   '선',
#   '없다',
#   '개',
#   '씨발'],
#  ['우리나라', '미개하다', '파퀴', '피다', '피다', '조선족', '이슬람', '새', '키', '넘치다'],
#  ['진짜',
#   '맘충',
#   '씨발',
#   '년',
#   '초',
#   '마다',
#   '존나',
#   '게',
#   '패',
#   '면서',
#   '똥',
#   '지리다',
#   '때',
#   '까지',
#   '패',
#   '고',
#   '싶다'],
#  ['이렇게', '메', '갈리다', '역사', '속', '사라지다', '병신', 'ㅋㅋㅋㅋ'],
#  ['자살', '을유', 'ㅐ'],
#  ['이런', '걸', '말꼬리', '잡다', '꼴', '페미', '해병대', '보내다'],
#  ['경상도',
#   '경기도',
#   '강원도',
#   '충청도',
#   '멍',
#   '청도',
#   '전',
#   'ㄹ',
#   '젓갈',
#   '로',
#   '만들다',
#   '버리다',
#   '잉'],
#  ['애', '데리', '고', '저', '지랄', '하노', 'ㅎㅎ', '차갑다', '확실하다', '안', '오다', '건너다'],
#  ['히잡', '을', '쓸다', '페미니스트', '모습', '이다'],
#  ['자기', '돈', '갈다', '생각', '없다', '건가'],
#  ['다문화',
#   '아니다',
#   '다',
#   '민족',
#   '다다',
#   '민족',
#   '에서',
#   '중국',
#   '제외',
#   '최소',
#   '화하다',
#   '다트',
#   '로',
#   '이의',
#   '목마',
#   '다'],
#  ['국물', '없다', '씨발련', '아', '라면', '이라도', '끓이다'],
#  ['틀', '딱', '섹스', '자체', '못'],
#  ['나', '한테', '이슬람', '좆', '칼푹찍', '권리', '달라', '이기', '조', '팔', '것'],
#  ['닛뽄',
#   '어르신',
#   '선진국',
#   '에서',
#   '태어나다',
#   '세',
#   '계위',
#   '국가',
#   '에서',
#   '자라',
#   '신분',
#   '헬',
#   '세다',
#   '틀',
#   '필리핀',
#   '이하',
#   '후진국',
#   '에서',
#   '태어나다',
#   '후진국',
#   '에서',
#   '사춘기',
#   '보내다',
#   '중진국',
#   '에서',
#   '전성기',
#   '보내다',
#   '한마디',
#   '로',
#   '촌놈'],
#  ['현기',
#   '준',
#   '중형',
#   '급',
#   '중형',
#   '급',
#   '이네',
#   '딱',
#   '보다',
#   '저',
#   '정도',
#   '컨트롤',
#   '안되다',
#   '보다',
#   '스팅어',
#   '랑',
#   '지',
#   '칠',
#   '공',
#   '제외',
#   '솔직하다',
#   '쉐보레',
#   '말리부',
#   '저',
#   '정도',
#   '커버',
#   '침'],
#  ['여성',
#   '신체',
#   '훼손',
#   '그',
#   '여자',
#   '소유',
#   '망상',
#   '을',
#   '충족',
#   '시키다',
#   '무슨',
#   '로미오',
#   '줄리엣',
#   '이라도',
#   '되다',
#   '양',
#   '일방',
#   '적',
#   '낭만',
#   '화하다',
#   '하노',
#   '에로스',
#   '적',
#   '인',
#   '충',
#   '동',
#   '살인',
#   '충',
#   '동',
#   '을',
#   '동시',
#   '느끼다',
#   '내다',
#   '들이다',
#   '생각',
#   '가장',
#   '극단',
#   '적',
#   '이고',
#   '이상',
#   '적',
#   '인',
#   '사랑',
#   '인데',
#   '노무',
#   '딱',
#   '미개하다'],
#  ['반찬', '틀', '딱', '입맛', '인데', '한국인', '저', '거', '최소', '살', '넘다', '좋아하다'],
#  ['저', '맘충', '결국', '광주', '인데', '정부', '에서', '안', '보호', '해주다'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋ', '집', '에서만', '게임', '안전하다', '이기', '야'],
#  ['언',
#   '젠',
#   '페미',
#   '우호',
#   '적',
#   '이다',
#   '척',
#   'ㅋ',
#   '누가',
#   '보다',
#   '맘충',
#   '김치',
#   '년',
#   '보전',
#   '깨등',
#   '천년',
#   '유구',
#   '여',
#   '혐',
#   '역사',
#   '다',
#   '웜탓할기세노됫'],
#  ['도대체',
#   '댓글',
#   '성비',
#   '왜',
#   '이르다',
#   'ㅋㅋㅋ',
#   '왤케',
#   '관심',
#   '많다',
#   'ㅋ',
#   '지다',
#   '들이다',
#   '뭘',
#   '안다',
#   '왤케',
#   '쿵쾅',
#   '대'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '봊',
#   '나',
#   '웃기',
#   '네',
#   '진짜',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['전라도', '대중', '목욕탕', '졸라', '많다'],
#  ['일', '천', '사건', '터지다', '주다', '아니다', '왜', '번', '몰다', '주다'],
#  ['이다', '옴', '감히', '이따', '구', '글', '사진', '을', '이렇게', '매치', '천벌', '을', '받다'],
#  ['사병', '말', '없다'],
#  ['백퍼', '그렇다'],
#  ['대다', '결코', '성인', '이라', '보다', '없다', '미숙', '나이다', 'ㅡㅡ'],
#  ['난', '애', '배다', '년', '와도', '안', '비키다', '줌'],
#  ['가리다', '있다', '안', '보이다'],
#  ['차다', '정신차려라'],
#  ['그래서', '이슬람', '싫다', '남다', '생각', '않다', '오직', '이슬람', '만', '안다'],
#  ['왜', '이슈', '지', 'ㅋㅋ', '쌍도', '쌍', '도지', '그렇다', '뭐라다', '씨팔'],
#  ['ㅇㅇ',
#   '발',
#   'ㅇㅇ',
#   '때문',
#   '라고',
#   '지하철',
#   '식당',
#   '카페',
#   '극장',
#   '휴양지',
#   '학원',
#   '술집',
#   '가다',
#   '곳',
#   '마다',
#   '사람',
#   '많다',
#   '이렇게',
#   '기사',
#   '쓰다',
#   '사람',
#   '욕',
#   '속이다',
#   '후련하다',
#   '하지만'],
#  ['마인드', '라도', '좋다'],
#  ['성', '님', '호르몬', '맞다', '충성'],
#  ['개슬람전', '라도', '반박', '시', '홍어', '인정'],
#  ['나다',
#   '관',
#   '에서',
#   '윾입되',
#   '서',
#   '관',
#   '웜글',
#   '가끔',
#   '퍼다',
#   '나르다',
#   '초',
#   '만에',
#   '삭제',
#   '되다',
#   '쀼젤'],
#  ['보지', '파티', '착하다', '퀴어', '어'],
#  ['갓', '럼프', '보다'],
#  ['우와', '명문', '중', '명문', '이다', 'ㅋㅋㅋㅋ'],
#  ['거',
#   '하나',
#   '맘',
#   '듭니',
#   '다',
#   '소수',
#   '특성',
#   '따르다',
#   '힘',
#   '커지다',
#   '얼마나',
#   '혼란',
#   '오다',
#   '지다',
#   '알',
#   '아',
#   '야하다'],
#  ['정통', '유대교', '애', '혼전', '떡', '치면', '뭐', '처벌', '같다', '안', '그냥', '용서', '해주다'],
#  ['아가리',
#   '때리다',
#   '버리다',
#   '싶다',
#   '조',
#   '랄',
#   '싫어하다',
#   '티',
#   '내다',
#   '왜케',
#   '지',
#   '저',
#   '분',
#   '거리',
#   '냐'],
#  ['무식하다',
#   '개',
#   '소리',
#   '추락',
#   '사라',
#   '단어',
#   '그렇다',
#   '포함',
#   '되어다',
#   '않다',
#   '그냥',
#   '떨어지다',
#   '죽다',
#   '추락',
#   '사임'],
#  ['군대',
#   '다시',
#   '나오다',
#   '때',
#   '다',
#   '민주화',
#   '당하다',
#   '것',
#   '모자라다',
#   '똥꼬',
#   '마저',
#   '내주다',
#   '야하다',
#   '군대',
#   '군대',
#   '냐'],
#  ['이분', '최소', '난박이'],
#  ['중딩', '말고는', '자다', '없다', 'ㅋㅋ', '정신승리', '계속', 'ㅎㅎ'],
#  ['대구', '메', '갈다', '퇘', '지', '보지', '젤', '만', 'ㅎ', '달다', '정설', '아니다'],
#  ['모',
#   '부',
#   '생일',
#   '선물',
#   '안',
#   '사주다',
#   '롤',
#   '오버',
#   '워치',
#   '현질',
#   '치다',
#   '대고',
#   '명품시계',
#   '타다',
#   '된장남',
#   '도살',
#   '답',
#   'ㅇㅇ'],
#  ['강용석', '말', '을', '저렇게', '그렇다', '사실', '어떻다', '보다', '맞다', '아니다'],
#  ['진짜', '미치다', '교', '인들', '죽겠네', '다', '하나님', '앞', '가라', '고'],
#  ['역시', '나', 'ㅎㅎ', '죽어랏'],
#  ['명불허전', '이네', 'ㅉㅉ'],
#  ['ㄹㅇ',
#   '개좃같',
#   '페미',
#   '민국',
#   '진짜',
#   '요즘',
#   '좌좀',
#   '달창',
#   '분탕년',
#   '남초',
#   '오지',
#   '게',
#   '풀다',
#   '더',
#   '만',
#   '애국',
#   '노예',
#   '처럼',
#   '살아가다',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['다', '늙다', '상폐좆놈', '어리다', '쇼린', '한테', '질투', '그렇다', '아니다'],
#  ['개학', '을', '안', '같다', '반', '아이', '부모', '안전하다', '아니다'],
#  ['급식', '패', '드립', '치다', '치다', '맞다', '야하다', '아니다'],
#  ['소수자',
#   '차별',
#   '않다',
#   '차별금지법',
#   '만들다',
#   '인간',
#   '당론',
#   '안',
#   '맞다',
#   '의원님',
#   '소수',
#   '의견',
#   '왜',
#   '존중',
#   '않다',
#   '차별',
#   '하나',
#   '진짜',
#   '모순',
#   '적',
#   '이고',
#   '자가',
#   '당착',
#   '적',
#   '이다'],
#  ['엑스', '맥스', '로', '업글', '하자'],
#  ['신발', '외', '노자', '다', '추방'],
#  ['개슬람', '새끼', '추방'],
#  ['진짜', '저건', '너무하다', 'ㅋㅋ'],
#  ['착하다',
#   '적자',
#   '린정',
#   '하노',
#   '한남',
#   '또',
#   '지다',
#   '좆',
#   '같다',
#   '일',
#   '저지르다',
#   '게',
#   '불보듯',
#   '뻔하다',
#   '일',
#   '아니다',
#   '영국',
#   '남자',
#   '그',
#   '따르다',
#   '즉각',
#   '적',
#   '인',
#   '행동',
#   '을',
#   '것',
#   '보이다',
#   '한남',
#   '오다',
#   '꾸다',
#   '보다',
#   '폭력',
#   '성',
#   '올라오다',
#   '것',
#   '당연하다',
#   '일',
#   '아니다',
#   '그',
#   '지다',
#   '영국',
#   '내다',
#   '적절하다',
#   '행동',
#   '을',
#   '뿐이다'],
#  ['내다', '연예인', '보지', '돈', '털다', '바쁘다'],
#  ['요즘', '살이', '면', '알다', '다', '알', '지'],
#  ['거', '날조', '자료', '라', '욕먹다', '딱', '좋다', '건데'],
#  ['폰', '작다', '가다', '황', '세미', '폭파', '원', '보다', 'ㄷㄷ'],
#  ['항상',
#   '댓글',
#   '왜',
#   '이렇다',
#   '의아',
#   '지금',
#   '상황',
#   '이렇게',
#   '바뀌다',
#   '중국',
#   '차다',
#   '무섭다',
#   '화나다'],
#  ['전라',
#   '년',
#   '똥',
#   '그',
#   '멍에',
#   '쑤시다',
#   '되다',
#   'ㅇㅇ',
#   '그',
#   '라야',
#   '복종',
#   '함',
#   '내',
#   '전라도',
#   '광주',
#   '다',
#   'ㅅㅂㅎㅎㅅ'],
#  ['ㅆㅂ', '된장국', '을', '얼굴', '달다'],
#  ['자아', '성찰', '쟤', '네', '다', '개돼지', '냄새', '나', 'ㅎㅌㅊ', '맞다'],
#  ['고작',
#   '위',
#   '밖에',
#   '안되다',
#   '보',
#   '니까',
#   '고위',
#   '직',
#   '여성',
#   '비율',
#   '영향',
#   '있다',
#   '보이다',
#   '차별',
#   '아니다',
#   '남성',
#   '의존',
#   '때문',
#   '이라는',
#   '한국',
#   '내부',
#   '사정',
#   '을',
#   '알다',
#   '다',
#   '거',
#   '반영',
#   '되다',
#   '난',
#   '위',
#   '찍다',
#   '보다'],
#  ['ㄹㅇㅋㅋㅋㅋㅋㅋ',
#   '뚱뚱하다',
#   '갖다',
#   '뒤뚱거리',
#   '유충',
#   '보다',
#   '속',
#   '너',
#   '작다',
#   '구나',
#   '라고',
#   '생각',
#   '쀼젤'],
#  ['치매',
#   '아버지',
#   '세상',
#   '에나',
#   '당신',
#   '진정하다',
#   '목사',
#   '되다',
#   '당신',
#   '아버지',
#   '광주',
#   '시민',
#   '앞',
#   '무릎',
#   '꿇다',
#   '빌어',
#   '야'],
#  ['중국',
#   '에서',
#   '조선족',
#   '년',
#   '만',
#   '난적',
#   '있다',
#   '술',
#   '먹다',
#   '갈다',
#   '때',
#   '마다',
#   '한족',
#   '새끼',
#   '시비',
#   '오지',
#   '게',
#   '털다'],
#  ['거',
#   '재미있다',
#   '남괘',
#   '밉다',
#   '블로그',
#   '글',
#   '쓰다',
#   '깝',
#   '치다',
#   '새끼',
#   '있다',
#   '신상',
#   '털다',
#   '보다'],
#  ['너', '아니다', '왜', '그렇게', '예민하다', 'ㅋㅋㅋㅋ', '웃챙'],
#  ['맨날',
#   '태국',
#   '짱깨',
#   '베트남',
#   '몽골',
#   '중앙',
#   '아시아',
#   '서남아시아',
#   '이렇다',
#   '인간',
#   '만',
#   '넘치다',
#   '들어오다',
#   '각',
#   '나라',
#   '마다',
#   '입국',
#   '수',
#   '제한',
#   '하자'],
#  ['저', '게', '목사', '냐', '사탄', '이지'],
#  ['ㅉ', '대가리', '빈', '새끼', '커피', '니', '네', '손', '타', '먹다', '말', '발', '박하다'],
#  ['무슬림',
#   '테러',
#   '하고',
#   '다니다',
#   '이유',
#   '새롭다',
#   '나라',
#   '도착',
#   '열심히',
#   '살다',
#   '신앙',
#   '생활',
#   '불편하다',
#   '느끼다',
#   '기존',
#   '살다',
#   '국민',
#   '충돌',
#   '점점',
#   '증오',
#   '쌓이다',
#   '자기',
#   '살',
#   '고',
#   '있다',
#   '나라',
#   '바꾸다',
#   '겠다',
#   '생각',
#   '을',
#   '폭탄',
#   '을',
#   '터뜨리다'],
#  ['대갈', '통', '크기', '보다'],
#  ['우디르'],
#  ['ㅋㅋㅋㅋㅋㅋ',
#   '자형',
#   '아니다',
#   '거의',
#   '직각',
#   '가깝다',
#   '도로',
#   '자르다',
#   '운전',
#   '미숙',
#   '이라는',
#   '새끼',
#   '뚜벅충',
#   '인증'],
#  ['엉덩이', '빵', '실하다', '창놈'],
#  ['탈북자',
#   '새끼',
#   '패싸움',
#   '일',
#   '상임',
#   '뭐더',
#   '라',
#   '북한',
#   '여자',
#   '나오다',
#   '토크쇼',
#   '거기',
#   '서',
#   '지다',
#   '들이다',
#   '말함',
#   '주먹다짐',
#   '아무',
#   '것',
#   '아니다',
#   '말',
#   '그대로',
#   '무법',
#   '지대'],
#  ['근데',
#   '나',
#   '만',
#   '그렇다',
#   '모르다',
#   '디씨',
#   '히어로',
#   '정이',
#   '안',
#   '매력',
#   '너무',
#   '없다',
#   '다',
#   '그냥',
#   'ㅈㄴ',
#   '쎄다',
#   '아이언맨',
#   '처럼',
#   '어떻다',
#   '히어로',
#   '되다',
#   '어떻다',
#   '단점',
#   '트라우마',
#   '끌어안다',
#   '있다',
#   '전혀',
#   '입체',
#   '적',
#   '이지',
#   '않다'],
#  ['돈', '만', '섬기다', '사람'],
#  ['다',
#   '생기다',
#   '괜찮다',
#   '남자',
#   '만',
#   '찍다',
#   '기럭지',
#   '짧다',
#   '옆',
#   '으론',
#   '두껍다',
#   '남성',
#   '형',
#   '유방',
#   '골반',
#   '면상',
#   '함몰',
#   '뒤통수',
#   '눌린',
#   '조선',
#   '보지',
#   '감히',
#   '비비다',
#   '못',
#   '레벨',
#   '인데',
#   '아무래도',
#   '은근',
#   '맘',
#   '들어서다',
#   '클리',
#   '비비다',
#   '때',
#   '쓰다',
#   '찍다'],
#  ['사',
#   '행시',
#   '존나',
#   '못',
#   '하',
#   '네',
#   '내',
#   '사',
#   '행시',
#   '지다',
#   '보다',
#   'ㅆㅂ',
#   '호',
#   '호주',
#   '국자',
#   '주',
#   '뒤지다',
#   '치다',
#   '맞다',
#   '국',
#   '정신',
#   '을',
#   '차리다'],
#  ['판검사',
#   '공부',
#   '분',
#   '이런',
#   '사람',
#   '위해',
#   '잘쓰다',
#   '그',
#   '아내',
#   '랑',
#   '동생',
#   '제',
#   '일',
#   '악질',
#   '인',
#   '듯'],
#  ['개', '만도', '못', '전라도', '시바'],
#  ['임신', '거', '아니다'],
#  ['진지하다',
#   '여성',
#   '존재',
#   '가치',
#   '뭐',
#   '냐',
#   '성욕',
#   '구',
#   '해결',
#   '출산',
#   '아니다',
#   '몸',
#   '을',
#   '화장',
#   '하고',
#   '꾸미다',
#   '자체',
#   '자기',
#   '자신',
#   '성적매력',
#   '을',
#   '높이다'],
#  ['한남', '죽이다', '힘', '조'],
#  ['보수',
#   '교단',
#   '보다',
#   '더',
#   '썩다',
#   '버리다',
#   '진보',
#   '교단',
#   '구',
#   '약학',
#   '교수',
#   '자다',
#   '있다',
#   '중국',
#   '교포',
#   '목사',
#   '국민일보',
#   '빨대',
#   '목사'],
#  ['네', '대한민국', '콜센터', '이다'],
#  ['무조건', '스시', '녀', '랑', '결혼', 'ㅋㅋ', '김치', '녀', '랑', '결혼', '이유', '없어지다'],
#  ['설거지', '보지', '털', '로', '뽀송뽀송하다'],
#  ['이슬람', '다르다', '모르다', '피', '싸개', '때리다', '잡다', '마음', '들다'],
#  ['반대',
#   '로',
#   '일',
#   '남충',
#   '김치',
#   '년',
#   '강간',
#   '강간범',
#   '일본',
#   '남자',
#   '피해자',
#   '한국',
#   '여자',
#   '로',
#   '오다',
#   '국적',
#   '부풀리다',
#   '반',
#   '일',
#   '선동',
#   '써다',
#   '먹다',
#   'ㅋㅋㅋㅋㅋㅋ'],
#  ['똑같다',
#   '성경',
#   '을',
#   '갖다',
#   '설교',
#   '목사',
#   '어떻다',
#   '가치관',
#   '을',
#   '갖다',
#   '따르다',
#   '코',
#   '걸다',
#   '코걸이',
#   '귀',
#   '걸다',
#   '귀걸이'],
#  ['한남', '좆', '부장', '제', '유지', '보지', '갈아', '넣다', '인생', '만이', '목표', '다'],
#  ['한국',
#   '교회',
#   '가다',
#   '지금',
#   '혹독하다',
#   '빙',
#   '맞다',
#   '있다',
#   '같다',
#   '퍼스트',
#   '펭귄',
#   '처럼',
#   '교총',
#   '을',
#   '중심',
#   '서로',
#   '연합',
#   '하고',
#   '사랑',
#   '이기다',
#   '바라다'],
#  ['항', '아니다', '항', '인데'],
#  ['깜빵', '같힌', '모습', '졸라', '멋지다'],
#  ['ㄹㅇ',
#   '그거',
#   '보고',
#   '컬쳐쇼크',
#   '신안군',
#   '경찰',
#   '보다',
#   'ㅋㅋㅋㅋ',
#   '우',
#   '덜',
#   '식',
#   '감싸다',
#   'ㅋㅋㅋㅋㅋㅋ',
#   '홍',
#   '통일체'],
#  ['틀', '딱', '들다', 'ㅂㄷㅂㄷㅋㅋ', '현실', '파악'],
#  ['미국', '강아지', '중국', '기사', '돌아다니다', '멍멍', '거리', '네'],
#  ['지다', '역차별', '멀다', 'ㅉㅉ', '페미', '정신병', '페미', '박멸'],
#  ['사상', '아웃', '아웃', '아웃'],
#  ['존나', '이쁘다', '존슨', '정신차리다', '저', '새끼', '잦다'],
#  ['여자',
#   '만들다',
#   '내다',
#   '남성',
#   '혐오',
#   '단어',
#   '왜캐',
#   '죄다',
#   '뇌',
#   '내',
#   '망상',
#   '에서나',
#   '온',
#   '단어',
#   '들이다'],
#  ['개종',
#   '그나마',
#   '괜찮다',
#   '난민',
#   '들어오다',
#   '개슬람',
#   '부르짖다',
#   '종자',
#   '다',
#   '추방',
#   '시키다',
#   '야하다'],
#  ['뭔', '소리'],
#  ['흑',
#   '인편',
#   '들다',
#   '경찰',
#   '공격',
#   '백인',
#   '보지',
#   '보다',
#   '총',
#   '갈겨',
#   '주다',
#   '싶다',
#   '흑인',
#   '한테',
#   '강간',
#   '당',
#   '해보다',
#   '정신차리다'],
#  ['난',
#   '살때',
#   '부터',
#   '정치',
#   '관심',
#   '있다',
#   '애초',
#   '난',
#   '책',
#   '을',
#   '제대로',
#   '읽다',
#   '시작',
#   '때',
#   '부터',
#   '신',
#   '자유주의자',
#   '이다',
#   '이명박',
#   '박근혜',
#   '노무현',
#   '김대중',
#   '문재인',
#   '비리',
#   '과거',
#   '같다',
#   '거',
#   '전혀',
#   '관심',
#   '없다',
#   '그냥',
#   '새끼',
#   '방향성',
#   '만',
#   '보다'],
#  ['그냥', '너', '네', '동네', '로', '가라', '누가', '잡다'],
#  ['다행하다', '분당', '아니다'],
#  ['그렇다',
#   '이번',
#   '마지막',
#   '기회',
#   '라',
#   '생각',
#   '하고',
#   '그리다',
#   '찾다',
#   '해매',
#   '이던',
#   '하나님',
#   '곁',
#   '갈다',
#   '여기',
#   '서',
#   '국민',
#   '께',
#   '민폐',
#   '두',
#   '혐오',
#   '감',
#   '주지',
#   '말고',
#   '가르다'],
#  ['경상도', '여자', '만나다', '싶다'],
#  ['저', '거', '구라', '다', '등신', '아', '선동', '당하다'],
#  ['허위',
#   '사실',
#   '대한',
#   '처벌',
#   '너무',
#   '약하다',
#   '지랄',
#   '기자',
#   '든',
#   '맘충',
#   '이든',
#   '가다',
#   '새끼',
#   '처벌',
#   '강하다',
#   '좋다'],
#  ['요즘',
#   '목사',
#   '하루',
#   '에도',
#   '몇',
#   '건',
#   '씩',
#   '건수',
#   '올리다',
#   '암튼',
#   '대단하다',
#   '이사회',
#   '암',
#   '덩어리',
#   '들이다',
#   '분명하다',
#   '같다'],
#  ['상폐남', 'ㅇㅣ', '안', '죽다', '어델', '기웃', '거리', '노', 'ㅋ'],
#  ['시발', '보기', '만해', '화나다'],
#  ['아싸', '헬', '렐레', '야'],
#  ['맹', '모', '삼천지교'],
#  ['민주화',
#   '찍다',
#   '애',
#   '민주화',
#   '테러',
#   '로',
#   '신고',
#   '짱깨',
#   '일',
#   '가능성',
#   '농후',
#   '나',
#   'ㄱㄱ',
#   '민주화',
#   '테러',
#   '신고',
#   '차단',
#   '성공하다',
#   'ㅋㅋ'],
#  ['그렇다', '경북', '인데', '창문', '열', '어보', '니', '집안', '보다', '따뜻하다'],
#  ['글', '쓸다', '놈', '맞다', '병신', '난독증', '새끼', '존나', '많다'],
#  ['거', '성차별', '아니다', '빼애애', '애액'],
#  ['있다'],
#  ['말다', '친구', '냐'],
#  ['ㅇㅇ', '좌빨', '기독', '무적', '조합', '이다'],
#  ['개슬람', '새끼', '싹', '다', '쓸다', '버리다'],
#  ['아',
#   '근데',
#   '게임',
#   '안',
#   '안되다',
#   '지금',
#   '구조',
#   '상',
#   '게임',
#   '개발자',
#   '사장',
#   '디자이너',
#   '다',
#   '한남',
#   '이라',
#   '한남',
#   '돈',
#   '벌다',
#   '거',
#   '밖에',
#   '안되다'],
#  ['저', '팬티', '벗다', '벌리다', '새끼', '칼', '을', '꽂다', '달라', '거', '냐'],
#  ['그런데', '여기다', '왜', '온', '거지', '그렇게', '좋다', '은나라', '면', '중국', '가지'],
#  ['오메',
#   '일베',
#   '가다',
#   'ㄷㄷ',
#   '근데',
#   '댓글',
#   '홍어',
#   '새끼',
#   '분위기',
#   '안',
#   '맞다',
#   '다짜고짜',
#   '경상도',
#   '대구',
#   '통구이',
#   '지랄',
#   '보다',
#   '어지간하다',
#   '부들부들',
#   '거리',
#   '나',
#   '보다',
#   'ㅋㅋ'],
#  ['이슬람',
#   '무슬림',
#   '인하다',
#   '문제점',
#   '만',
#   '보지',
#   '말다',
#   '왜',
#   '그',
#   '이슬람',
#   '을',
#   '믿다',
#   '살다',
#   '번',
#   '알아보다',
#   '것',
#   '좋다',
#   '제',
#   '생각',
#   '엔',
#   '분명',
#   '뭔가',
#   '있다',
#   '교회',
#   '나',
#   '성',
#   '당가',
#   '고',
#   '절',
#   '다니다',
#   '사람',
#   '처럼',
#   '그',
#   '에게도',
#   '이슬람',
#   '뭔가',
#   '의미',
#   '있다',
#   '믿다'],
#  ['폭도', '대한민국', '국적', '인정', '해주다', '고맙다', '씨발', 'ㅋㅋ'],
#  ['박원순', '기획', '보다', '마즘', '참여연대', '정보', '력'],
#  ['좆', '같다', '진짜'],
#  ['근데', '진짜', '저', '만해', '리얼', '팩트', '임', '진짜', '로', '풀발', '저', '정도'],
#  ['일',
#   '본',
#   '애',
#   '드리다',
#   '정부',
#   '말',
#   '순종',
#   '적',
#   '인',
#   '가장',
#   '대표',
#   '적',
#   '이고',
#   '고',
#   '전적',
#   '인',
#   '이유',
#   '자연재해'],
#  ['이만갑', '나오다', '목사', '네'],
#  ['가다',
#   '학',
#   '자해',
#   '가득하다',
#   '항문',
#   '성관계',
#   '정상',
#   '이라고',
#   '전',
#   '국민',
#   '세뇌',
#   '시키다',
#   '정의당',
#   '인권',
#   '팔이',
#   '장사치',
#   '괄약근',
#   '얼마나',
#   '더',
#   '늘어나다',
#   '정신차리다'],
#  ['닉', '존나', '크다', '여운', '대', '왜그렛', '냐', '안다', '가다'],
#  ['보다', '자세하다', '자료', '흑형', '호감', '장난', '아니다'],
#  ['저기',
#   '서',
#   '성소수자',
#   '빼다',
#   '유리하다',
#   '땐',
#   '여자',
#   '돼다',
#   '불리하다',
#   '땐',
#   '남자',
#   '돼다',
#   '이르다',
#   '인간'],
#  ['또', '유튜브', '규제', '시', '동거', '네'],
#  ['개', '꼴', '씨발', 'ㅋㅋㅋㅋ'],
#  ['홍어', '새끼', '물', '타다', '지리다'],
#  ['물',
#   '타다',
#   '오지',
#   '네',
#   '군인',
#   '신분',
#   '보고',
#   '없이',
#   '수술',
#   '말',
#   '되다',
#   '일단',
#   '처벌',
#   '받다',
#   '그다음',
#   '말',
#   '말다',
#   '해',
#   '라'],
#  ['일',
#   '전요',
#   '딱',
#   '일',
#   '소문',
#   '퍼지다',
#   '기간',
#   '해명',
#   '기회',
#   '주지',
#   '않다',
#   '수',
#   '있다',
#   '기간',
#   '이라',
#   '일',
#   '일',
#   '나오다',
#   '가능성',
#   '크다',
#   '겁니다'],
#  ['ㅎㄴㅊ', '또'],
#  ['ㅂㅈ', '년', '남자', '빡치다', '밀치다', '나르다', '뇌진탕', '걸리다', '뒤지다'],
#  ['이형', '맞다'],
#  ['나', '이브', '단어', '들다', 'ㄹㅇ', '이노', '좆팔', 'ㅋㅋㅋㅋㅋ'],
#  ['평등', '아니다', '여성', '상위', '원하다', '불만', '이지'],
#  ['보다', '애', '아'],
#  ['에이',
#   'ㅅㅂ',
#   'ㅋㅋ',
#   '나라',
#   '주도하다',
#   '짓',
#   '아니다',
#   '개인',
#   '저',
#   '지랄',
#   '나라',
#   '국격',
#   '떨어지다',
#   '말',
#   '이나',
#   '되다'],
#  ['아웃', '라이어', '읽다'],
#  ['동성', '을', '사랑', '권리', '있다', '동성애', '싫어하다', '권리', '있다', '것', '이다'],
#  ['의학',
#   '적지',
#   '식이',
#   '얼마나',
#   '있다',
#   '모르다',
#   '선',
#   '무당',
#   '말',
#   '이렇게',
#   '언론',
#   '타다',
#   '게',
#   '그리다',
#   '좋다',
#   '보이지',
#   '않다'],
#  ['금오공대', '생', '쓸다', '글', '맞다', '수준', '보다', 'ㅋㅋ'],
#  ['막상',
#   '입국심사대',
#   '앞',
#   '서면',
#   'ㅈㄴ',
#   '쫄',
#   '게',
#   '무슨',
#   '투쟁',
#   '을',
#   '해',
#   '경찰',
#   '한테',
#   '대들다',
#   '순간',
#   '바로',
#   '추방',
#   '이지',
#   'ㅋㅋ',
#   '입국',
#   '주요',
#   '인물',
#   '로',
#   '찍히다',
#   '입국심사대',
#   '통과',
#   '못',
#   '하고',
#   '그대로',
#   '한국',
#   '돌아오다',
#   '꿀',
#   '재다',
#   '미국',
#   '입국심사',
#   '에서',
#   '추방',
#   '당하다',
#   '그때',
#   '부터',
#   '미국',
#   '땅',
#   '밟다',
#   '거의',
#   '불가능',
#   '인데'],
#  ['그래도', '쟤', '지다', '들다', '한국인', '이라고', '우기다', '뭘', '요구', '않다'],
#  ['개떵꺼', '같다', '키'],
#  ['무식하다',
#   '의사',
#   '놈',
#   '태국',
#   '의료',
#   '체계',
#   '좆',
#   '나다',
#   '무시',
#   '전염병',
#   '방역',
#   '체계',
#   '순위',
#   '전세계',
#   '위',
#   '국가',
#   '태국',
#   '이다',
#   '대한민국',
#   '위로',
#   '태국',
#   '보다',
#   '아래',
#   '순',
#   '위임'],
#  ['고소', '당하다', '빨갛다', '그', '어', '지다', '정신', '슨리', '수', '있다'],
#  ['세상',
#   '에서',
#   '젤',
#   '찌질하다',
#   '한남',
#   'ㅉㅉ',
#   '여성',
#   '할당',
#   '제',
#   '지랄',
#   '실상',
#   '지다',
#   '들이다',
#   '자지',
#   '달리다',
#   '걸',
#   '로',
#   '혜택',
#   '젤',
#   '많이',
#   '받다',
#   '으',
#   '엑'],
#  ['위',
#   '벌써',
#   '예수',
#   '쟁이',
#   '들다',
#   '몰려오다',
#   '변명',
#   '늘어놓다',
#   '보다',
#   'ㅋㅋㅋ',
#   '저러다',
#   '개독',
#   '소리',
#   '듣다',
#   '지다',
#   '들다',
#   '모름',
#   '저',
#   '새끼',
#   '공룡',
#   '이고',
#   '뭐',
#   '고',
#   '전부',
#   '주작',
#   '이라고',
#   '생각',
#   '함',
#   '그냥',
#   '정신',
#   '병자'],
#  ['저딴',
#   '새',
#   '키도',
#   '자식',
#   '있다',
#   '부끄러움',
#   '을',
#   '알다',
#   '그걸',
#   '모르다',
#   '짐승',
#   '새',
#   '키',
#   '지'],
#  ['이마트',
#   '가면',
#   '예일',
#   '프린스턴',
#   '콜룸비',
#   '아',
#   '등등',
#   '저런',
#   '식',
#   '아이비리그',
#   '대학',
#   '옷',
#   '파다',
#   '저런',
#   '게',
#   '멀다',
#   '의미',
#   '있다',
#   'ㅋㅋㅋㄲ',
#   '븅',
#   '신들',
#   '이노'],
#  ['목사',
#   '저러다',
#   '저런',
#   '목사',
#   '로부터',
#   '가르침',
#   '을',
#   '받다',
#   '신도',
#   '안',
#   '보다',
#   '비디오',
#   '다'],
#  ['아무렇다',
#   '미래',
#   '소득',
#   '없다',
#   '애',
#   '새끼',
#   '명',
#   '씩',
#   '싸지르다',
#   '유럽',
#   '난민',
#   '이라는',
#   '명목',
#   '들어가다',
#   '강간',
#   '유럽',
#   '정복',
#   '거',
#   '다',
#   '이르다',
#   '새끼',
#   '을',
#   '보고',
#   '좌파',
#   '물',
#   '고',
#   '빨다',
#   '유럽',
#   '병신'],
#  ['보다', '씨발', '김치', '녀', '보다', '더', '시급하다', '삼일한', '보빨남', '이다'],
#  ['아', '입', '근', '질', '근', '질', '데'],
#  ['탈북자',
#   '대한',
#   '지원이',
#   '너무',
#   '많다',
#   '그리고',
#   '우리나라',
#   '에서',
#   '받다',
#   '고맙다',
#   '영국',
#   '미국',
#   '씨발'],
#  ['자랑', '얼굴', '까지', '끄다'],
#  ['이딴', '소설', '믿다', '딱', '딱', '충', '있다'],
#  ['성경', '에도', '동성애', '죄', '로', '나오다'],
#  ['자지', '새끼', '침', '뱉다', '좆', '나', '개', '걸레', '창놈', '같다'],
#  ['조',
#   '선발',
#   '페미',
#   '문화',
#   '일본',
#   '을',
#   '오염시키다',
#   '김치',
#   '최종',
#   '적',
#   '인',
#   '문화',
#   '승리',
#   '다'],
#  ['개븅쉰새퀴', '김치', '육', '변기', '창년', '허벌빡대가뤼', '박다', '짓', 'ㅂ'],
#  ['너무', '디'],
#  ['박',
#   '시장',
#   '어쨌든',
#   '죄',
#   '없다',
#   '해',
#   '라',
#   '그게',
#   '더불다',
#   '입장',
#   '라는',
#   '거',
#   '말',
#   '안해',
#   '안다'],
#  ['요',
#   '씨발',
#   '짱깨',
#   '새끼',
#   '보',
#   '소등',
#   '국민',
#   '한족',
#   '이란',
#   '다',
#   '개',
#   '씹다',
#   '짱',
#   '퀴',
#   '벌레',
#   '새끼',
#   '야',
#   '짱',
#   '퀴나',
#   '좆족',
#   '이나',
#   '다',
#   '똑같다',
#   '씹다',
#   '버러지',
#   '지',
#   '뭐',
#   '다르다',
#   '은근',
#   '짱퀴',
#   '빨다',
#   '딱',
#   '걸리다'],
#  ['애초', '착불', '안', '진행', '을', '말다'],
#  ['ㅇㄱㄹㅇ',
#   '비겁하다',
#   '평화',
#   '낫다',
#   '고',
#   '그냥',
#   '저렇게',
#   '살',
#   '게',
#   '내다',
#   '두다',
#   '무슨',
#   '민족',
#   '애',
#   '타령',
#   'ㅋㅋ',
#   '다문화',
#   '소외',
#   '시키다',
#   '인권',
#   '팔이',
#   '가만히',
#   '있다'],
#  ['조선족', '틀', '딱', '색', '히', '들다', '물다', '하제'],
#  ['미국',
#   '에서',
#   '아동',
#   '성범죄',
#   '징역',
#   '이면',
# ...
#   '이슈',
#   '화',
#   '말고',
#   '각자',
#   '부르다',
#   '싶다',
#   '대로',
#   '불다',
#   '기자',
#   '떠들다',
#   '바뀌다',
#   '아니다'],
#  ['자살', '똥꼬', '충'],
#  ['자지', '멸종', '앙망'],
#  ['씨',
#   'ㅣㅅ',
#   '펄트젠',
#   '여자',
#   '지',
#   '남자',
#   '냐',
#   '불리하다',
#   '땐',
#   '평등',
#   '요구',
#   '실제',
#   '로는',
#   '배척',
#   '나쁘다',
#   '여자',
#   '나다',
#   '여자',
#   '지만',
#   '이건',
#   '아니다',
#   '트젠',
#   '입학',
#   '공부',
#   '왜',
#   '포기',
#   '거',
#   '야',
#   '보다',
#   '듯이',
#   '입학',
#   '싸우다',
#   '무너지다',
#   '그',
#   '마음',
#   '응원',
#   '하고',
#   '힘내다',
#   '여자',
#   '군대',
#   '가다'],
#  ['서',
#   '양충',
#   '입장',
#   '에서는',
#   '우리',
#   '랑',
#   '교미',
#   '우리',
#   '똥남',
#   '이랑',
#   '교미',
#   '똑같이',
#   '느끼다'],
#  ['좆', 'ㄸㅔ', '부르다', '네', '이런', '새끼', '남자', '냐', '여자', '냐', '이제'],
#  ['짓', '보다', '명예', '홍어', '박사모', '아니다', 'ㅋㅋㅋㅋㅋ'],
#  ['전라도',
#   '랑',
#   '경상도',
#   '남쪽',
#   '지방',
#   '진짜',
#   '답',
#   '없다',
#   '쓰레기',
#   '인간',
#   '개',
#   '많다',
#   '신안',
#   '이랑',
#   '부산',
#   '이런',
#   '곳',
#   '진짜',
#   '너무',
#   '쓰레기',
#   '이라',
#   '믿다',
#   '힘들다',
#   '정도',
#   '임',
#   '전북',
#   '이랑',
#   '경북',
#   '정상',
#   '이고',
#   '서울',
#   '경기도',
#   '충북',
#   '제일',
#   '나다'],
#  ['이슬람',
#   '난민',
#   '받다',
#   '때',
#   '아니다',
#   '해도',
#   '받다',
#   '세',
#   '세다',
#   '호의',
#   '잊다',
#   '권리',
#   '만',
#   '있다',
#   '뿐',
#   '이다'],
#  ['막', '짤', '아', '휴', '진짜'],
#  ['ㅋㅋㅋㅋㅋ', '놀다', '때', '존나', '안', '스럽다', 'ㅋㅋㅋㅋ'],
#  ['나',
#   '기숙사',
#   '식당',
#   '돼지고기',
#   '나',
#   '올',
#   '때',
#   '개슬람',
#   '새끼',
#   '만',
#   '따로',
#   '뭐',
#   '하나',
#   '해주다',
#   '이렇게',
#   '시발'],
#  ['저',
#   '거',
#   '연기',
#   '임',
#   'ㅋㅋㅋ',
#   '친구',
#   '병원',
#   '이슬람',
#   '노동자',
#   '새끼',
#   '오다',
#   '돼지고기',
#   '자다',
#   '처',
#   '먹다',
#   '몰래',
#   '몰래'],
#  ['두번째',
#   '사진',
#   '트럼프',
#   '표정',
#   '앵',
#   '나오다',
#   '사진',
#   '계속',
#   '올라오다',
#   'ㅋㅋㅋㅋㅋㅋ',
#   '세번',
#   '째',
#   '사진',
#   '트럼프',
#   '표정',
#   '앵',
#   '나오다'],
#  ['동성애',
#   '치료',
#   '필요',
#   '로',
#   '질병',
#   '임',
#   '을',
#   '명확하다',
#   '동성애자',
#   '치료',
#   '통해',
#   '건강하다',
#   '삶',
#   '을',
#   '회복하다',
#   '것',
#   '진정하다',
#   '인권',
#   '이다'],
#  ['매',
#   '예배',
#   '마다',
#   '젖다',
#   '눈동자',
#   '뜨겁다',
#   '목젖',
#   '울먹거리다',
#   '가슴',
#   '주님',
#   '을',
#   '찬양',
#   '기',
#   '도합',
#   '니',
#   '다',
#   '첫사랑',
#   '감격',
#   '을',
#   '회복하다',
#   '원하다',
#   '우선',
#   '저',
#   '부터',
#   '그리고',
#   '한국',
#   '교회',
#   '모두'],
#  ['천조국',
#   '같다',
#   '바로',
#   '총',
#   '알받이',
#   '넫',
#   '아숩',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '무슬림',
#   '시발',
#   '세',
#   '키덜'],
#  ['그렇다', '일베', '에도', '이다', '들이다', '있다', '무슨'],
#  ['걸', '보다'],
#  ['내다',
#   '들다',
#   '다',
#   '백치',
#   '아다다',
#   '글',
#   '읽다',
#   '쓰기',
#   '개빻았는데',
#   '무슨',
#   '작가',
#   '질',
#   '군대',
#   '힘',
#   '다',
#   '바질',
#   '때',
#   '까지',
#   '짱',
#   '박아',
#   '두다',
#   '노예',
#   '처럼',
#   '쓰다',
#   '답'],
#  ['오다', '시발', '성경', '깔다', '새끼', '있다'],
#  ['할랄',
#   '같다',
#   '소리',
#   '애',
#   '미디',
#   '진',
#   '새끼',
#   '문화',
#   '안',
#   '맞다',
#   '오지',
#   '말다',
#   '휴',
#   '씨발',
#   '그것',
#   '아니다',
#   '니',
#   '셀프',
#   '로',
#   '참수',
#   '뒤지다',
#   '해',
#   '라',
#   '캭',
#   '퉤',
#   '씨팔',
#   '기분',
#   '좆',
#   '같다'],
#  ['저러다', '해봤다', '욕', '만', '치다', '먹다', '왜', '피해망상', '있다'],
#  ['깔다', '갈다', '깔깔', '깔깔'],
#  ['남자',
#   '나',
#   '여자',
#   '나',
#   '외모',
#   '나',
#   '몸매',
#   '적',
#   '매력',
#   '없다',
#   '사람',
#   '외면',
#   '받다',
#   '그걸',
#   '성차별',
#   '로',
#   '생각',
#   '그냥',
#   '매력',
#   '없다',
#   '임',
#   '여자',
#   '로써'],
#  ['착하다', '인종청소', '인정'],
#  ['뭔',
#   '듣보잡',
#   '대학',
#   '이냐',
#   '이름',
#   '존나',
#   '촌스럽다',
#   '전라도',
#   '대학',
#   '전남대',
#   '랑',
#   '지스트',
#   '만',
#   '들다',
#   '보다'],
#  ['걸',
#   '우리나라',
#   '에서',
#   '세금',
#   '퍼',
#   '부다',
#   '대',
#   '공',
#   '까지',
#   '합세',
#   '이유',
#   '뭡',
#   '니까',
#   '미치다',
#   '나라',
#   '죠',
#   '애',
#   '죽이다',
#   '하나요',
#   '정신차리다',
#   '정치',
#   '인들'],
#  ['돈',
#   '많이',
#   '들다',
#   '리스크',
#   '크다',
#   '출산',
#   '률',
#   '정책',
#   '보다는',
#   '돈안',
#   '고',
#   '대외',
#   '이미지',
#   '까지',
#   '좋아지다',
#   '난민',
#   '외다',
#   '수입',
#   '정권',
#   '한테',
#   '늘다',
#   '안전',
#   '빵',
#   '이지',
#   '진짜',
#   '목숨',
#   '걸다',
#   '출산',
#   '률',
#   '정책',
#   '관철',
#   '시키다',
#   '정권',
#   '필요하다',
#   '대선',
#   '때',
#   '제대로',
#   '짚다',
#   '야하다',
#   '포인트',
#   '다'],
#  ['내',
#   '주변',
#   '만',
#   '해도',
#   '여자',
#   'ㅅㅌㅊ',
#   '들다',
#   '애',
#   '명',
#   '만',
#   '낳다',
#   '전문',
#   '대졸',
#   '여자',
#   '애',
#   '명',
#   '씩',
#   '낳다'],
#  ['바', '한번', '가다', '면', '오피', '싸다', '먹히다', '물론', '내', '얘기', '아니다'],
#  ['세인트', '고', '재기'],
#  ['치안',
#   '개',
#   '쓰레기',
#   '엘살바도르',
#   '영어',
#   '안',
#   '통한',
#   '달다',
#   '식',
#   '으로만',
#   '설명',
#   '버리다',
#   '살인',
#   '율',
#   '세',
#   '계위',
#   '나라'],
#  ['대단하다',
#   '신분',
#   '이야',
#   '페미니즘',
#   '우리',
#   '사회',
#   '얼마나',
#   '주',
#   '도세',
#   '력',
#   '인지',
#   '전혀',
#   '모르다',
#   '사실',
#   '상',
#   '못',
#   '배우다',
#   '신분',
#   '같다',
#   '애'],
#  ['이렇다',
#   '개',
#   '같다',
#   '경우',
#   '있다',
#   '사람',
#   '생명',
#   '보다',
#   '지다',
#   '들다',
#   '정치',
#   '적',
#   '집회',
#   '더',
#   '중요하다',
#   '이상하다',
#   '교회',
#   '네',
#   '신도',
#   '을',
#   '죽음',
#   '유도',
#   '목사',
#   '아니다',
#   '악마',
#   '이다'],
#  ['줄', '서', '있다', '애', '들보', '면', '다리', '부러', '트리', '고', '싶다', '정상', '임'],
#  ['남자', '페미니스트', '없다', '페미니스트', '응원', '남펜', '만', '있다', '뿐'],
#  ['말', '좋다', '성소수자', '지', '저', '것', '시발', '병균', '만들다', '쓰레기', '아니다'],
#  ['고거', '상황', '지켜보다', '그런', '거래', '나', '뭐', '래', '나'],
#  ['역시',
#   '보지',
#   '인생',
#   '부터',
#   '사실',
#   '저',
#   '대장',
#   '나이',
#   '몇',
#   '살인',
#   '지',
#   '모르다',
#   '대충',
#   '찍다',
#   '이기',
#   '야',
#   '자지',
#   '하나',
#   '죽',
#   '이고',
#   '년',
#   '복역',
#   '공부',
#   '다',
#   '하고',
#   '잘살다',
#   '있다',
#   '깔깔',
#   '깔다'],
#  ['동성애',
#   '인권',
#   '아니다',
#   '적나라하다',
#   '드러나다',
#   '같다',
#   'ㅜㅜㅜ',
#   '인권',
#   '아니다',
#   '개인',
#   '성적',
#   '쾌락',
#   '만',
#   '추구',
#   '동성애',
#   '절대',
#   '반대',
#   '이다',
#   'ㅠ'],
#  ['조선족',
#   '자체',
#   '가짜',
#   '아니다',
#   '만주족',
#   '지다',
#   '들다',
#   '만주족',
#   '인거',
#   '숨다',
#   '언어',
#   '비슷하다',
#   '생기다',
#   '비슷하다',
#   '한국인',
#   '코스'],
#  ['군인',
#   '권',
#   '센터',
#   '소장',
#   '병사',
#   '에서',
#   '장교',
#   '나',
#   '부사관',
#   '지원',
#   '전역',
#   '병사',
#   '간부',
#   '두다',
#   '경험',
#   '해보다',
#   '사람',
#   '되다',
#   '저런',
#   '동성애',
#   '병역기피',
#   '그냥',
#   '군',
#   '앙심',
#   '을',
#   '품다',
#   '불순',
#   '의도',
#   '가지다',
#   '밖에',
#   '없다'],
#  ['보지', '쪽내', '드리다'],
#  ['초등학교', '이름', '점'],
#  ['근데', '터키', '저런', '게', '필요하다', '같다', '병신', '같다', '이슬람', '에서', '탈피'],
#  ['더불다',
#   '초창',
#   '기',
#   '메르스',
#   '개다',
#   '뛰놀다',
#   '갓',
#   '치',
#   '아',
#   '스타트',
#   '끊다',
#   '봊나',
#   '게',
#   '고맙다'],
#  ['대구',
#   '좆',
#   '영',
#   '업자',
#   '씨발',
#   'ㅋㅋㅋㅋㅋ',
#   '언제',
#   '최저임금',
#   '챙기다',
#   '주다',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '챙기다',
#   '저',
#   '지랄',
#   '을',
#   '하던갘',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['내다', '왜', '급소', '밖', '내놓다', '다니다', '미개하다', '같다'],
#  ['이래서', '내다', '들다', '돈', '을', '쥐다', '안되다', '임', 'ㅉㅉ'],
#  ['김진태',
#   '크다',
#   '충',
#   '조지',
#   '선봉',
#   '장',
#   '역할',
#   '대통령',
#   '까지',
#   '지내다',
#   '하필',
#   '박',
#   '그네',
#   '개',
#   '짓거리',
#   '하',
#   '바람',
#   'ㅅㅂ'],
#  ['그', 'ㅅㄲ', '페미니스트', '대통령', '되다'],
#  ['냄새', '나다', '벌금', '물리다', '야하다', '후팔', '인간', '재떨이', '재기'],
#  ['그렇다',
#   '성',
#   '소수자',
#   '비난',
#   '맙시',
#   '다',
#   '동성',
#   '똥구녕',
#   '단지',
#   '그립다',
#   '사람',
#   '일',
#   '뿐이다',
#   '남탕',
#   '가기',
#   '싫다'],
#  ['진짜', '헛구역질', '나다'],
#  ['아', '게이', '인간', '너무', '혐오', '스럽다'],
#  ['북',
#   '따르다',
#   '딱',
#   '딱',
#   '은뭐노',
#   '흑',
#   '좆',
#   '나',
#   '쇼타',
#   '응디',
#   '마냥',
#   '입',
#   '착착',
#   '감다',
#   '북',
#   '따르다',
#   '딱',
#   '딱',
#   '북',
#   '딱',
#   '딱'],
#  ['제발', '다', '삭발', '해주다', 'ㅠㅠ', '믿다', '거르', '게', '시발', '년', '아'],
#  ['양쪽',
#   '말',
#   '들다',
#   '보다',
#   '거',
#   '위험하다',
#   '동아제약',
#   '인가',
#   '면접',
#   '보고',
#   '쓸다',
#   '글',
#   '소름',
#   '돋다',
#   '첨',
#   '진짜',
#   '웃기다',
#   '회사',
#   '네',
#   '그랬는데',
#   '같이',
#   'ㄹ',
#   '어가',
#   '서',
#   'ㅜ',
#   '면',
#   '접본',
#   '남자',
#   '글',
#   '보고',
#   '사람',
#   '같다',
#   '박아',
#   '들이다',
#   '이렇게',
#   '다르다',
#   '느끼다',
#   '약간',
#   '정신병',
#   '이지',
#   '않다',
#   '싶다'],
#  ['원', '바', '뭐', '냐'],
#  ['궁금하다',
#   '있다',
#   '똥꼬',
#   '충',
#   '보다',
#   '여자',
#   '똥꼬',
#   '쑤시다',
#   '섹스',
#   '배다',
#   '많다',
#   '에이즈',
#   '똥꼬',
#   '충',
#   '많이',
#   '걸리다'],
#  ['ㄴ',
#   '지다',
#   '들다',
#   '페미',
#   '안',
#   '맞다',
#   '페미',
#   '공부',
#   '앵앵',
#   '앵앵',
#   '이러니까',
#   '페미',
#   '안',
#   '사람',
#   '나오다',
#   '진짜',
#   '머',
#   '가리다',
#   '왜',
#   '들다',
#   '다니다',
#   '모르다',
#   'ㅋㅋ'],
#  ['댓개빻았노', '재기', '남', '개', '많다', '재기', '시키다', '버리다', '야하다'],
#  ['태극기',
#   '할배',
#   '차',
#   '없다',
#   '면허증',
#   '없다',
#   '기름값',
#   '톨',
#   '비도',
#   '없다',
#   '막걸리',
#   '값',
#   '오만원',
#   '씩',
#   '받다',
#   '나오다'],
#  ['씨발', '아저씨', '하위호환', '이네'],
#  ['건강하다', '예배', '회복', '을', '위해', '함께', '기도'],
#  ['똥꼬', '충', '박멸'],
#  ['어리다', '부터', '보고', '배우다', '그', '만의', '성', '문화', '라서'],
#  ['뭐노', '나', '만', '안', '뜨다'],
#  ['예민', '충', '좆복치'],
#  ['중국인',
#   '인정',
#   '마인드',
#   '좋다',
#   '이기',
#   '야',
#   '근데',
#   '씨발',
#   '뭔',
#   '동포',
#   '니',
#   '차별',
#   '이니',
#   '개',
#   '지랄',
#   '말다',
#   '외국인',
#   '이면',
#   '서',
#   '한국',
#   '서다',
#   '뭔',
#   '도움',
#   '그렇다',
#   '햣',
#   '늘다'],
#  ['한남', '문', '한남', '답'],
#  ['졸리', '끔찍하다'],
#  ['이슬람',
#   '그나마',
#   '동남아',
#   '똥송',
#   '인종',
#   '보다',
#   '이쁘다',
#   '인종',
#   '개량',
#   '가능',
#   '을',
#   '노리다',
#   '수',
#   '있다'],
#  ['사상', '바로', '선', '분', '이네'],
#  ['뒤통수', '삽', '후리다', '다음', '저', '흙', '파서', '그대로', '묻다'],
#  ['조선족', '민주당', '권리', '당', '원전', '라도', '맘충', '개돼지', '혼종임'],
#  ['싹', '다', '태우다', '부러'],
#  ['질', '않다', '조아'],
#  ['ㅋㅋㅋㅋㅋㅋ', '유잼', '예상'],
#  ['고스트바둑왕', '개꿀', '재다'],
#  ['표준어', '괜히', '표준어', '냐'],
#  ['죽다', '빨갱이', '년'],
#  ['수영장', '오다', '틀', '딱', '들다', '진심', '죽이다'],
#  ['똥꼬',
#   '충',
#   '새끼',
#   '그냥',
#   '자살',
#   '전부',
#   '해결',
#   '되다',
#   '즙',
#   '왜',
#   '질질',
#   '짜다',
#   '자빠지다',
#   '개',
#   '씹다',
#   '쌔끼',
#   '내',
#   '일본도',
#   '로',
#   '죽이다',
#   '버리다',
#   '싶다'],
#  ['이렇다',
#   '여가부',
#   '에서',
#   '앞장서다',
#   '유감',
#   '표명',
#   '되다',
#   '아니다',
#   '해당',
#   '시',
#   '의원',
#   '중',
#   '여',
#   '성',
#   '의원',
#   '반',
#   '대안',
#   '하',
#   '나'],
#  ['게이', '새끼', '시발', '나가다', '처', '뒤지다', '근데', '레즈', '예술', '오'],
#  ['틀', '풍', '불다', '민주당', '다시', '떡', '상', 'ㅠㅠ'],
#  ['진짜', '자지', '새끼', '나대다', '보다', '머', '갈다', '뜯다', '버리다'],
#  ['교활', '아', '너', '나', '변절', '사드', '세월호', '것', '만으로도', '넌'],
#  ['근',
#   '데',
#   '요',
#   '예수',
#   '믿다',
#   '천국',
#   '가다',
#   '예수',
#   '믿다',
#   '사람',
#   '왜',
#   '아직도',
#   '살',
#   '아',
#   '있다',
#   '나',
#   '같다',
#   '빨리',
#   '죽다',
#   '천국',
#   '가다'],
#  ['경상도',
#   '새끼',
#   '나',
#   '전라도',
#   '새끼',
#   '나',
#   '겪다',
#   '보다',
#   '두',
#   '새끼',
#   '다',
#   '좆',
#   '같다',
#   '경기',
#   '서',
#   '울',
#   '충북',
#   '강원',
#   '충남',
#   '가축',
#   '경상',
#   '전',
#   '북제주',
#   '전남'],
#  ['쉬다',
#   '헐다',
#   '지',
#   '롤',
#   '허다',
#   '밀가루',
#   '찌다',
#   '하나',
#   '가지',
#   '고',
#   '개',
#   '지랄',
#   '염병',
#   '을',
#   '해',
#   '라'],
#  ['전', '북평', '화', '인권연대', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['전라도', '중국', '짱깨', '미만', '임', 'ㅇㅇ', '전라도', '인', '억', '존재', '상상', '보다'],
#  ['저러다',
#   '진짜',
#   '지푸라기',
#   '라도',
#   '잡',
#   '을',
#   '사람',
#   '계속',
#   '해결',
#   '책',
#   '찾다',
#   '눈',
#   '돌아가다',
#   '저러다',
#   '홀리',
#   '지',
#   '저런',
#   '곳도',
#   '사람',
#   '얼마나',
#   '절박',
#   '한지',
#   '보고',
#   '저런',
#   '물',
#   '바로',
#   '주지',
#   '않다',
#   '신도',
#   '되다',
#   '돈',
#   '받치다',
#   '까맣다',
#   '밀땅함'],
#  ['판사', '기독교인', '가보다', '년', '이르다'],
#  ['번탈남', '컨셉', '아주', '참신하다', '놐', 'ㅋㅋㅋㅋ', '프로젝트', '로', '밀다', '야하다'],
#  ['닥치고',
#   '홍어',
#   '다',
#   '죽이다',
#   '야하다',
#   '종족',
#   '자체',
#   '옆집',
#   '죽다',
#   '자기',
#   '가족',
#   '만',
#   '잘살다',
#   '주의',
#   '임',
#   '한마디',
#   '로',
#   '개새끼'],
#  ['니',
#   '네',
#   '정신',
#   '적',
#   '지주',
#   '인',
#   '이국주',
#   '음식',
#   '시키다',
#   '때',
#   '많이',
#   '시키다',
#   '쪽팔리다',
#   '친구',
#   '있다',
#   '척',
#   'ㅋㅋㅋㅋ',
#   '미치다',
#   '년',
#   '아'],
#  ['김대중',
#   '기념',
#   '센터',
#   '옆',
#   '새누리당',
#   '지부',
#   '짓다',
#   '거',
#   '랑',
#   '비슷하다',
#   '꼴임',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['말', '되다'],
#  ['저렇다', '다시', '기어', '들어오다', '검머외', '노릇', '아니다'],
#  ['머구다',
#   '그런데',
#   '어디',
#   '냐',
#   '혹시',
#   '일베',
#   '사무실',
#   '위치',
#   '그',
#   '통구이',
#   '인간',
#   '백정',
#   '만',
#   '산다',
#   '그',
#   '곳',
#   '이냐'],
#  ['볼',
#   '만',
#   '하노',
#   '근데',
#   '웜년들',
#   '입맛',
#   '엔',
#   '안',
#   '맞다',
#   '근데',
#   '거',
#   '라도',
#   '어디',
#   '냐',
#   '안',
#   '그렇다',
#   '요즘',
#   '보다',
#   '없다',
#   '그래도',
#   '허다',
#   '벌다',
#   '추다',
#   '삼',
#   '가해',
#   '라',
#   '이기',
#   '야',
#   'ㅋㅋㅋ'],
#  ['저년', '때문', '동남아', '년', '사람', '안보', '인', '다'],
#  ['도쿄', '있다', '양', '놈', '오다', '꾸다', '한국', '있다', '루저', '보단', '훨씬', '낫', '덥다'],
#  ['저러다', '만원', '못', '주다', '저러다'],
#  ['난', '급식', '철', '없이', '지랄', '구경', '젤', '재밌다', 'ㅋㅋ'],
#  ['조팔',
#   '저',
#   '게',
#   '년도',
#   '선진국',
#   '에서',
#   '일어나다',
#   '일이',
#   '라니',
#   '믿다',
#   '없다',
#   '내',
#   '조국',
#   '좆',
#   '되다',
#   '기전',
#   '무슬람',
#   '좆',
#   '새끼',
#   '막다',
#   '야하다',
#   '전세계',
#   '지구',
#   '상',
#   '어디',
#   '없다',
#   '한남',
#   '을',
#   '이기다',
#   '여',
#   '혐좆',
#   '한테',
#   '정복',
#   '당하다',
#   '생기다'],
#  ['아가씨', '패러디', '문', '구노', '찾아보다', '라이', '니'],
#  ['역시', '갓', '순신', '이유', '있다', '외치다', '갓', '순신'],
#  ['이쁘다', '애가', '생각', '바르다'],
#  ['노', '키즈', '존', '노맘충존'],
#  ['아',
#   '옆',
#   '씨발',
#   '년',
#   '깔다',
#   '짝',
#   '대다',
#   '존나',
#   '짜증나다',
#   '버러지',
#   '같다',
#   '창년',
#   '진짜',
#   'ㅡㅡ'],
#  ['왜',
#   '박근혜',
#   '라',
#   '때',
#   '거슬리다',
#   '자댕',
#   '들다',
#   '재기',
#   '놈',
#   '성재기',
#   '님',
#   '웅앵',
#   '이르다',
#   '박근혜',
#   '대통령',
#   '님',
#   '박근혜',
#   '띡',
#   '이렇게',
#   '부르다',
#   '최초',
#   '대통령',
#   '시',
#   '니',
#   '만큼',
#   '봊',
#   '나',
#   '올리다',
#   '치다',
#   '야하다'],
#  ['저',
#   '게이',
#   '즈',
#   '충',
#   '후',
#   '장',
#   '짬지',
#   '꼽',
#   '고',
#   '지랄',
#   '게',
#   '이즈',
#   '걸리다',
#   '아니다',
#   '누가',
#   '보다',
#   '정부',
#   '인위',
#   '적',
#   '감염',
#   '시키다',
#   '알다',
#   '후팔'],
#  ['니', '댓글달다', '때', '성추행', '드립', '작작하다', '댓글달다'],
#  ['아편',
#   '맞다',
#   '어렵다',
#   '일',
#   '있다',
#   '어떻다',
#   '해결',
#   '생각',
#   '되다',
#   '하느님',
#   '아버지',
#   '이르다',
#   '있다'],
#  ['참으로',
#   '노력',
#   '들다',
#   '욕',
#   '을',
#   '욕',
#   '을',
#   '그렇다',
#   '들다',
#   '징글',
#   '징글',
#   '하',
#   '다',
#   '교',
#   '인들',
#   '진짜',
#   '지구',
#   '상',
#   '을',
#   '그냥',
#   '떠나다',
#   '교인',
#   '아'],
#  ['대다', '대', '차이', '아가리', '똥내', '에서부터', '차이나다'],
#  ['빙의', '차로', '싹', '쓸다', '버리다', '좋다'],
#  ['잡히다',
#   '사람',
#   '중',
#   '에서',
#   '유명인',
#   '있다',
#   '경우',
#   '그',
#   '사람',
#   '성향',
#   '여론',
#   '향방',
#   '영향',
#   '주다',
#   '미투',
#   '때',
#   '우파',
#   '잡다',
#   '터트렸는데',
#   '좌파',
#   '많이',
#   '걸리다',
#   '이번',
#   '어떻다'],
#  ['똑같이',
#   '동등',
#   '기회',
#   '주다',
#   '년',
#   '결과',
#   '존나',
#   '안좋다',
#   '달성',
#   '률',
#   '떨어지다',
#   '그래서',
#   '위',
#   '결론',
#   '김치',
#   '녀',
#   '수준',
#   '위인',
#   '거지',
#   '여자',
#   '지다',
#   '들다',
#   '얼굴',
#   '침',
#   '뱉다',
#   '꼴'],
#  ['유대',
#   '인들',
#   '보다',
#   '다',
#   '답',
#   '나오다',
#   '않다',
#   '세계',
#   '문화',
#   '전부',
#   '하나님',
#   '믿다',
#   '민족',
#   '인',
#   '유태인',
#   '세상',
#   '을',
#   '바꾸다',
#   '안',
#   '믿다',
#   '이유',
#   '있다'],
#  ['뭔',
#   '개',
#   '소린',
#   '지',
#   '모르다',
#   '사진',
#   '병신',
#   '같이',
#   '찍다',
#   '컴터',
#   '외',
#   '엔',
#   '뭘',
#   '찍다',
#   '건지다',
#   '모르다'],
#  ['어느',
#   '나라',
#   '든지',
#   '그',
#   '나라',
#   '관습',
#   '예절',
#   '사회',
#   '적',
#   '이념',
#   '풍습',
#   '등등',
#   '모두',
#   '다르다',
#   '우리나라',
#   '에서는',
#   '아직',
#   '동성',
#   '간',
#   '성결',
#   '합',
#   '인정',
#   '어렵다',
#   '사회',
#   '아니다',
#   '대부분',
#   '남자',
#   '끼리',
#   '생활',
#   '군대',
#   '에서는',
#   '안되다',
#   '맞다'],
#  ['보들보들', 'ㅋㅋ'],
#  ['형님', '걱정', '되다'],
#  ['한국',
#   '년',
#   '가격',
#   '개비',
#   '싸다',
#   '갯수',
#   '제한',
#   '이니',
#   '뭐',
#   '안',
#   '돼다',
#   '뭐',
#   '안',
#   '돼다',
#   '몸',
#   '팔다',
#   '곳',
#   '에서조차',
#   '존나',
#   '까다롭다',
#   '움',
#   '그리고',
#   '몸',
#   '팔다',
#   '것',
#   '싫다',
#   '센슈얼',
#   '이라는',
#   '딸딸방',
#   '보지',
#   '년',
#   '존나',
#   '많다',
#   'ㅋㅋ',
#   '그러나',
#   '중국',
#   '여자',
#   '한국',
#   '년',
#   '보다',
#   '가리다',
#   '거',
#   '없다'],
#  ['동성애', '반대', '죽이다', '놈', '인가', '인정', '달라', '것', '만', '표현', '자유', '인가'],
#  ['적그리스도'],
#  ['외',
#   '노자',
#   '한국',
#   '에서',
#   '벌다',
#   '자국',
#   '송금',
#   '버는거',
#   '나',
#   '마찬가지',
#   '그렇다',
#   '싱글벙글',
#   '즐겁다',
#   '일',
#   '택배',
#   '상',
#   '하차',
#   '사람',
#   '주다',
#   '싱글벙글',
#   '웃다',
#   '일',
#   '걸'],
#  ['그래서', '홍준', '연', '구', '의원', '을', '민주당', '에서', '제명', '시키다', '당인', '가보다'],
#  ['맞다', '말다', '에이즈', '동성애', '원인', '맞다'],
#  ['작성자', '공익', '이냐'],
#  ['폭동', '유공', '탈북', '년놈', '돈', '회수', '바람', '닭', '재인', '띠'],
#  ['동성애',
#   '남자',
#   '끼리',
#   '항문성교',
#   '구강성교',
#   '여지',
#   '끼리',
#   '구강성교',
#   '더럽다',
#   '짖다',
#   '그냥',
#   '변태',
#   '이다',
#   '너희',
#   '끼리',
#   '해',
#   '라',
#   '인정',
#   '해달라다',
#   '마르다'],
#  ['존나', '웃기다', '어이', '없다', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['아크용접',
#   '연습',
#   '많이',
#   '해',
#   '라',
#   '이기',
#   '그리고',
#   '여기',
#   '이렇다',
#   '해',
#   '라',
#   '저렇다',
#   '해',
#   '라',
#   '훈수',
#   '충논',
#   '많다',
#   '여러가지',
#   '해보다',
#   '너',
#   '가편',
#   '거해',
#   '라'],
#  ['앙', '대지', '띠'],
#  ['고맙다',
#   '생각',
#   '병신',
#   '아',
#   '너',
#   '같이',
#   '맨날',
#   '조선조',
#   '한테',
#   '짱깨',
#   '라고',
#   '놀리다',
#   '새끼',
#   '땜',
#   '힘드다'],
#  ['김치', '년', '진성', '빨갱남', '한테', '늘다', '상대', '안되다', '잇다'],
#  ['메', '갈리아', '완전', '개념', '사이트', '아니다'],
#  ['남자', '올바르다', '표본', '쿨', '제', '이필', '굿'],
#  ['박근혜', '이명박', '둘', '한테', '아쉽다', '다문화', '다', '씨발'],
#  ['망', '가가', '최고', '징'],
#  ['세상',
#   '변화',
#   '하고',
#   '있다',
#   '것',
#   '같다',
#   '기쁘다',
#   '변화',
#   '맞추다',
#   '단계',
#   '발전',
#   '되다',
#   '대한민국',
#   '되어다'],
#  ['저런', '한남', '새끼', '때문', '더', '울화', '치밀', '고', '빡치다'],
#  ['ㅋㅋㅋㅋㅋ',
#   '아',
#   '생각',
#   '해보다',
#   '개',
#   '웃기다',
#   'ㅋㅋㅋㅋ',
#   '경',
#   '엽',
#   '이형도',
#   '밤',
#   '마다',
#   '막대기',
#   '꼽',
#   '고',
#   '자다',
#   '갑자기',
#   '궁금하다',
#   '그걸',
#   '옆',
#   '에서',
#   '보다',
#   '남충',
#   '키부',
#   '니',
#   '어떻다',
#   '노오'],
#  ['연세대',
#   '이다',
#   '뺴박',
#   '관원',
#   '교',
#   '이다',
#   '정장',
#   '애인',
#   '샤대',
#   '이다',
#   '이미',
#   '졸업',
#   'ㅇㄱㅇㄱ',
#   '동성애자',
#   '우기',
#   '고',
#   '우기다',
#   '몇',
#   '십년',
#   '만에',
#   '정상인',
#   '인증',
#   '받다',
#   '내다',
#   '앞',
#   '으론',
#   '동물',
#   '성애자',
#   '나',
#   '아동',
#   '성애자',
#   '정상인',
#   '취급',
#   '받다',
#   '날',
#   '오다',
#   '말세',
#   '지',
#   '말세',
#   'ㅉㅉ'],
#  ['삼륜', '안', 'ㄷㄷㄷㄷ'],
#  ['다음',
#   '역시',
#   '빨',
#   '갱',
#   '사이트',
#   '답',
#   '다',
#   '댓글',
#   '만',
#   '보다',
#   '잠재',
#   '테러',
#   '국',
#   '지정',
#   '되다'],
#  ['하', '존나', '끄다', '깝', '색', '히노', '그렇다', '땐', '나가다', '헌팅', '이라도'],
#  ['꼬추', '작다', '식사', '매너', '최저', '한국', '남자', '뒤지다'],
#  ['다른',
#   '전략',
#   '똥',
#   '냐',
#   '사이트',
#   '똥',
#   '냐',
#   '인척',
#   '자지',
#   '몰카',
#   '올리다',
#   '퍼뜨리',
#   '것',
#   '을',
#   '생각',
#   '사실',
#   '이미',
#   '똥',
#   '냐',
#   '사이트',
#   '자지',
#   '몰카',
#   '많다'],
#  ['마리', '검거'],
#  ...]

# %%
# 빈도수가 낮은 단어들이 훈련 데이터에서 얼만큼의 비중을 차지가
threshold = 3
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 24044
# 등장 빈도가 2번 이하인 희귀 단어의 수: 14816
# 단어 집합에서 희귀 단어의 비율: 61.62036266844119
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 5.969665415823493

# %%
vocab_size = total_cnt - rare_cnt + 1
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 9229

# %%
tokenizer = Tokenizer(vocab_size) # 빈도수 2 이하인 단어는 제거
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
y_train = np.array(train['target'])
y_test = np.array(test['target'])

# %%
print(len(X_train))
print(len(y_train))
# Out:
# 22479
# 22479

# %%
drop_train = [index for index, sentence in enumerate(X_train) if len(sentence) < 1]
drop_test = [index for index, sentence in enumerate(X_test) if len(sentence) < 1]

# %%
len(drop_train)
# Out:
# 56

# %%
X_train = np.delete(X_train, drop_train, axis=0)
y_train = np.delete(y_train, drop_train, axis=0)
# Out:
# /Users/hk/miniforge3/envs/tf/lib/python3.8/site-packages/numpy/lib/function_base.py:4454: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asarray(arr)

# %%
print(len(X_train))
print(len(y_train))
print(len(X_test))
print(len(y_test))
# Out:
# 22423
# 22423
# 5592
# 5592

# %%
X_test = np.delete(X_test, drop_test, axis=0)
y_test = np.delete(y_test, drop_test, axis=0)

print(len(X_test))
print(len(y_test))
# Out:
# 5571
# 5571

# %%
import matplotlib.pyplot as plt

# %%
print('리뷰의 최대 길이 :',max(len(l) for l in X_train))
print('리뷰의 평균 길이 :',sum(map(len, X_train))/len(X_train))
plt.hist([len(s) for s in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 72
# 리뷰의 평균 길이 : 10.306471034205948

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))*100))

# %%
max_len = 30
below_threshold_len(max_len, X_train)
# Out:
# 전체 샘플 중 길이가 30 이하인 샘플의 비율: 96.43669446550417

# %%
from keras.preprocessing.sequence import pad_sequences

# %%
# 전체 데이터의 길이는 30으로 맞춘다.
X_train = pad_sequences(X_train, maxlen = max_len)
X_test = pad_sequences(X_test, maxlen = max_len)

# %%
embedding_dim = 128
hidden_units = 128

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
# model.add(Bidirectional(LSTM(hidden_units))) # Bidirectional LSTM을 사용
model.add(LSTM(hidden_units))
model.add(Dense(1, activation='sigmoid'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_model_LSTM.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=10, callbacks=[es, mc], batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/10
# 281/281 [==============================] - 8s 28ms/step - loss: 0.4177 - acc: 0.8061 - val_loss: 0.4659 - val_acc: 0.7924
#
# Epoch 00001: val_acc improved from -inf to 0.79242, saving model to best_model_LSTM.h5
# Epoch 2/10
# 281/281 [==============================] - 8s 28ms/step - loss: 0.2822 - acc: 0.8766 - val_loss: 0.4624 - val_acc: 0.8011
#
# Epoch 00002: val_acc improved from 0.79242 to 0.80111, saving model to best_model_LSTM.h5
# Epoch 3/10
# 281/281 [==============================] - 8s 28ms/step - loss: 0.2513 - acc: 0.8930 - val_loss: 0.6188 - val_acc: 0.7202
#
# Epoch 00003: val_acc did not improve from 0.80111
# Epoch 4/10
# 281/281 [==============================] - 8s 28ms/step - loss: 0.2310 - acc: 0.9014 - val_loss: 0.5822 - val_acc: 0.7492
#
# Epoch 00004: val_acc did not improve from 0.80111
# Epoch 5/10
# 281/281 [==============================] - 8s 28ms/step - loss: 0.2146 - acc: 0.9091 - val_loss: 0.5581 - val_acc: 0.7400
#
# Epoch 00005: val_acc did not improve from 0.80111
# Epoch 6/10
# 281/281 [==============================] - 8s 28ms/step - loss: 0.1977 - acc: 0.9188 - val_loss: 0.6152 - val_acc: 0.7532
#
# Epoch 00006: val_acc did not improve from 0.80111
# Epoch 00006: early stopping

# %%
loaded_model = load_model('best_model_LSTM.h5')

print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))
# Out:
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3404 - acc: 0.8526
#
#  테스트 정확도: 0.8526

# %%
preds = loaded_model.predict(X_test)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score

# clf = LogisticRegression(solver="liblinear", random_state=0).fit(X_test, y_test)

# roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1]) 
AUC = roc_auc_score(y_test, preds)     

# y_pred = model.predict(test_labels)
precision = precision_score(y_test, np.round(abs(preds))) 
f1 = f1_score(y_test, np.round(abs(preds))) 

print("AUC : ", AUC)
print("Precision Score : ", precision)
print("f1 Score : ", f1)
# Out:
# AUC :  0.9320852324603665
# Precision Score :  0.8393960192175703
# f1 Score :  0.8562926658498161
