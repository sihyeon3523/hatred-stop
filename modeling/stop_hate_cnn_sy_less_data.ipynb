# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.5.0'

# %%
import konlpy
import sklearn
import tensorflow

print(konlpy.__version__) # 0.5.2
print(sklearn.__version__) # 1.0.2
print(tensorflow.__version__) # 2.8.0
# Out:
# 0.5.2
# 1.1.1
# 2.5.0

# %% [markdown]
# # 1. 데이터 수집 & 전처리

# %%
import pandas as pd
import urllib.request
import matplotlib.pyplot as plt
import re
from konlpy.tag import Okt
from tqdm import tqdm
from tensorflow.keras.preprocessing.text import Tokenizer
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
train_data = pd.read_csv("./data/unsmile_train_less.csv")
test_data = pd.read_csv("./data/unsmile_valid_less.csv")

# %%
print('훈련 샘플의 개수 :',len(train_data)) # 훈련용 리뷰 개수 출력
print('테스트 샘플의 개수 :',len(test_data)) # 테스트용 리뷰 개수 출력
# Out:
# 훈련 샘플의 개수 : 15005
# 테스트 샘플의 개수 : 3737

# %%
train_data.rename(columns={'문장':'sentence'}, inplace=True)
test_data.rename(columns={'문장':'sentence'}, inplace=True)

# %%
train_data[:5] # 상위 5개 출력
# Out:
#    Unnamed: 0                                           sentence  target
# 0           0                             일안하는 시간은 쉬고싶어서 그런게 아닐까       0
# 1           1  아동성범죄와 페도버는 기록바 끊어져 영원히 고통 받는다. 무슬림 50퍼 근친이다. ...       1
# 2           2  루나 솔로앨범 나왔을 때부터 머모 기운 있었음 ㅇㅇ Keep o  doin 진짜 띵...       0
# 3           3  홍팍에도 어버이연합인가 보내요 뭐 이런뎃글 있는데 이거 어버이연합측에 신고하면 그쪽...       0
# 4           4  아놔 왜 여기 댓들은 다 여자들이 김치녀라고 먼저 불렸다! 여자들은 더 심하게 그런...       1

# %%
train_data['sentence'].nunique(), train_data['target'].nunique()
# Out:
# (15004, 2)

# %%
train_data.drop_duplicates(subset=['sentence'], inplace=True) # document 열에서 중복인 내용이 있다면 중복 제거

# %%
print('총 샘플의 수 :',len(train_data))
# Out:
# 총 샘플의 수 : 15004

# %%
train_data['target'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
print(train_data.groupby('target').size().reset_index(name = 'count'))
# Out:
#    target  count
# 0       0   3738
# 1       1  11266

# %%
print(train_data.isnull().values.any())
# Out:
# False

# %%
print(train_data.isnull().sum())
# Out:
# Unnamed: 0    0
# sentence      0
# target        0
# dtype: int64

# %%
train_data.loc[train_data.sentence.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, sentence, target]
# Index: []

# %%
train_data = train_data.dropna(how = 'any') # Null 값이 존재하는 행 제거
print(train_data.isnull().values.any()) # Null 값이 존재하는지 확인
# Out:
# False

# %%
print(len(train_data))
# Out:
# 15004

# %%
train_data['sentence'] = train_data['sentence'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# 한글과 공백을 제외하고 모두 제거
train_data[:5]
# Out:
# <ipython-input-18-f2430c7e0838>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['sentence'] = train_data['sentence'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
#    Unnamed: 0                                           sentence  target
# 0           0                             일안하는 시간은 쉬고싶어서 그런게 아닐까       0
# 1           1  아동성범죄와 페도버는 기록바 끊어져 영원히 고통 받는다 무슬림 퍼 근친이다  까지 ...       1
# 2           2     루나 솔로앨범 나왔을 때부터 머모 기운 있었음 ㅇㅇ     진짜 띵곡임 꼭 들어보셈       0
# 3           3  홍팍에도 어버이연합인가 보내요 뭐 이런뎃글 있는데 이거 어버이연합측에 신고하면 그쪽...       0
# 4           4  아놔 왜 여기 댓들은 다 여자들이 김치녀라고 먼저 불렸다 여자들은 더 심하게 그런다...       1

# %%
train_data['sentence'] = train_data['sentence'].str.replace('^ +', "") # white space 데이터를 empty value로 변경
train_data['sentence'].replace('', np.nan, inplace=True)
print(train_data.isnull().sum())
# Out:
# Unnamed: 0     0
# sentence      24
# target         0
# dtype: int64
# <ipython-input-19-bc5c82268599>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['sentence'] = train_data['sentence'].str.replace('^ +', "") # white space 데이터를 empty value로 변경

# %%
train_data.loc[train_data.sentence.isnull()][:5]
# Out:
#       Unnamed: 0 sentence  target
# 572          572      NaN       0
# 1054        1054      NaN       0
# 1469        1469      NaN       1
# 1646        1646      NaN       1
# 1996        1996      NaN       0

# %%
train_data = train_data.dropna(how = 'any')

# %%
print(len(train_data))
# Out:
# 14980

# %%
test_data.drop_duplicates(subset = ['sentence'], inplace=True) # document 열에서 중복인 내용이 있다면 중복 제거
test_data['sentence'] = test_data['sentence'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
test_data['sentence'] = test_data['sentence'].str.replace('^ +', "") # 공백은 empty 값으로 변경
test_data['sentence'].replace('', np.nan, inplace=True) # 공백은 Null 값으로 변경
test_data = test_data.dropna(how='any') # Null 값 제거
print('전처리 후 테스트용 샘플의 개수 :',len(test_data))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 3730
# <ipython-input-23-37159e8dcb43>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   test_data['sentence'] = test_data['sentence'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
# <ipython-input-23-37159e8dcb43>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   test_data['sentence'] = test_data['sentence'].str.replace('^ +', "") # 공백은 empty 값으로 변경

# %%
print('전처리 후 테스트용 샘플의 개수 :',len(test_data))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 3730

# %%
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
okt = Okt()

# %%
X_train = []
for sentence in tqdm(train_data['sentence']):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_train.append(stopwords_removed_sentence)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 14980/14980 [01:05<00:00, 229.58it/s]

# %%
X_test = []
for sentence in tqdm(test_data['sentence']):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_test.append(stopwords_removed_sentence)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 3730/3730 [00:19<00:00, 187.56it/s]

# %%
print('전처리 후 테스트용 샘플의 개수 :',len(X_test))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 3730

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
print(tokenizer.word_index)
# Out:
# {'을': 1, '새끼': 2, '보다': 3, '아니다': 4, '되다': 5, '있다': 6, '다': 7, '없다': 8, '로': 9, '같다': 10, '이다': 11, '안': 12, '저': 13, '에서': 14, '만': 15, '나': 16, '여자': 17, '고': 18, '못': 19, '들다': 20, 'ㅋㅋ': 21, '좆': 22, '아': 23, '거': 24, '왜': 25, '그렇다': 26, '야': 27, '적': 28, '사람': 29, '그': 30, '하고': 31, '진짜': 32, '게': 33, '년': 34, 'ㅋㅋㅋ': 35, '말': 36, '가다': 37, '것': 38, '남자': 39, '않다': 40, '이기': 41, '인': 42, '받다': 43, '존나': 44, '네': 45, '좋다': 46, '한남': 47, '지': 48, '더': 49, '개': 50, '니': 51, '뭐': 52, '오다': 53, '먹다': 54, '한국': 55, '생각': 56, '씨발': 57, '애': 58, 'ㅋㅋㅋㅋ': 59, '라': 60, '내': 61, '충': 62, '면': 63, '많다': 64, '지다': 65, '딱': 66, '알다': 67, '페미': 68, '그냥': 69, '맞다': 70, '인데': 71, '한테': 72, '때': 73, '놈': 74, '치다': 75, '나오다': 76, '임': 77, '하': 78, '일': 79, '전라도': 80, '냐': 81, '병신': 82, '들이다': 83, '시발': 84, '시키다': 85, '나라': 86, '나다': 87, '모르다': 88, '살다': 89, '내다': 90, '똥꼬': 91, '돈': 92, '쓰다': 93, '서': 94, '이나': 95, '보지': 96, '글': 97, '동성애': 98, '저런': 99, '일베': 100, '홍어': 101, '안되다': 102, '버리다': 103, '수': 104, '틀': 105, '근데': 106, '라고': 107, '랑': 108, '목사': 109, '싶다': 110, '게이': 111, '교회': 112, '까지': 113, 'ㅋㅋㅋㅋㅋ': 114, '지랄': 115, '이노': 116, '해주다': 117, '남': 118, '이렇다': 119, '성': 120, '만들다': 121, '주다': 122, '함': 123, '후': 124, 'ㅋ': 125, '문제': 126, '야하다': 127, '부터': 128, '다니다': 129, '중국': 130, '김치': 131, '짱깨': 132, '어떻다': 133, '개독': 134, '중': 135, '지금': 136, '생기다': 137, '난': 138, '조선족': 139, '싫다': 140, '이랑': 141, '무슨': 142, '이슬람': 143, '여': 144, '우리': 145, '하나': 146, 'ㅋㅋㅋㅋㅋㅋ': 147, '또': 148, '자지': 149, '요': 150, '끄다': 151, '죽이다': 152, '대다': 153, '소리': 154, '돼다': 155, '똥': 156, '때문': 157, '대': 158, '이라고': 159, '자다': 160, '이지': 161, '걸': 162, '믿다': 163, 'ㄹㅇ': 164, '너': 165, '기': 166, '이고': 167, '종교': 168, '뭔': 169, '노': 170, '보고': 171, '저러다': 172, '처럼': 173, '미치다': 174, '씹다': 175, '정신병': 176, '이라': 177, '정도': 178, '재기': 179, '죽다': 180, '당하다': 181, '갈다': 182, '자기': 183, '장': 184, '녀': 185, '따다': 186, '해': 187, '시': 188, '너무': 189, '살': 190, '개슬람': 191, '맘충': 192, '남충': 193, '국민': 194, '같이': 195, '차다': 196, '뒤지다': 197, '라도': 198, '다른': 199, '크다': 200, '에게': 201, '이제': 202, '라는': 203, '급식': 204, '늘다': 205, '무슬림': 206, '사회': 207, '이네': 208, '님': 209, '인간': 210, '많이': 211, '짓': 212, '여성': 213, '세상': 214, '욕': 215, '제': 216, '해보다': 217, '신': 218, '되어다': 219, '우리나라': 220, '수준': 221, '이냐': 222, '기사': 223, '써다': 224, '답': 225, '전': 226, '이야': 227, '정신': 228, '혐오': 229, '결혼': 230, '역시': 231, '반대': 232, '요즘': 233, '차별': 234, '건': 235, '제발': 236, '누가': 237, '명': 238, '알': 239, '문': 240, '사실': 241, '군대': 242, '미국': 243, '법': 244, '니까': 245, '당': 246, '이렇게': 247, '쓸다': 248, '댓글': 249, '좋아하다': 250, '새': 251, '조': 252, '말다': 253, '끼리': 254, '인정': 255, '줄': 256, '이해': 257, '자체': 258, '인권': 259, '난민': 260, '국가': 261, '쌍': 262, '집': 263, '보이다': 264, '소': 265, '이유': 266, '다르다': 267, '깔다': 268, '빨다': 269, '다문화': 270, '절대': 271, '저렇게': 272, 'ㅅㅂ': 273, '보내다': 274, '그리고': 275, '머': 276, '올리다': 277, '얼마나': 278, '구': 279, '오': 280, '한번': 281, '대한민국': 282, '일본': 283, '데': 284, '분': 285, '에이즈': 286, '인가': 287, '뿐': 288, '화': 289, '메': 290, '기독교': 291, '찍다': 292, '처': 293, '쟤': 294, '걸리다': 295, '어디': 296, '엔': 297, '하노': 298, '밉다': 299, '페미니즘': 300, '당연하다': 301, '쓰레기': 302, '정말': 303, '짤': 304, '미개하다': 305, '양': 306, '이런': 307, '그렇게': 308, '키': 309, '정상': 310, '더럽다': 311, '위': 312, '젠': 313, '성소수자': 314, '인지': 315, '깔깔': 316, '두다': 317, '거리': 318, '들어가다': 319, '듯': 320, '남다': 321, '패': 322, '동성애자': 323, '그게': 324, '말고': 325, '북한': 326, '곳': 327, '앞': 328, '얼굴': 329, '잡다': 330, '상': 331, '솔직하다': 332, '두': 333, '아이': 334, '뭘': 335, '거지': 336, '웃기다': 337, '눈': 338, '밖에': 339, '읽다': 340, '몇': 341, '놓다': 342, '주': 343, '이건': 344, '반': 345, '나가다': 346, 'ㅉㅉ': 347, '예수': 348, '경상도': 349, '서다': 350, '급': 351, '피': 352, '꼴': 353, '집단': 354, '아주': 355, '섹스': 356, '넘다': 357, '강간': 358, '모든': 359, '뜨다': 360, '입다': 361, '에도': 362, '다시': 363, '만나다': 364, '입': 365, '에는': 366, '뽑다': 367, '앵': 368, '한국인': 369, '여기': 370, '이라도': 371, '이라는': 372, '꼭': 373, '이상': 374, '개새끼': 375, '사진': 376, '망하다':  ...

# %%
print(tokenizer.word_counts.items())
# Out:
# odict_items([('이다', 974), ('시간', 70), ('쉬다', 54), ('그렇다', 662), ('아니다', 1516), ('아동', 15), ('성범죄', 25), ('페도버', 1), ('기록', 4), ('바', 38), ('끊어지다', 1), ('영원하다', 14), ('고통', 18), ('받다', 519), ('무슬림', 154), ('퍼', 29), ('근', 30), ('친', 30), ('까지', 257), ('떨어지다', 60), ('출산', 31), ('위험', 7), ('다', 1486), ('루나', 1), ('솔로', 1), ('앨범', 1), ('나오다', 376), ('때', 402), ('부터', 229), ('머모', 5), ('기운', 4), ('있다', 1505), ('ㅇㅇ', 70), ('진짜', 635), ('띵곡임', 1), ('꼭', 84), ('들다', 755), ('보다', 1566), ('홍팍', 2), ('에도', 86), ('어버이연합', 2), ('인가', 108), ('보내다', 115), ('뭐', 471), ('이런', 102), ('뎃글', 1), ('거', 684), ('측', 5), ('신고', 48), ('그', 640), ('쪽', 59), ('에서', 917), ('고소', 26), ('가능하다', 59), ('아', 702), ('놓다', 92), ('왜', 679), ('여기', 85), ('댓', 19), ('여자', 814), ('김치', 226), ('녀', 165), ('라고', 267), ('먼저', 40), ('불리다', 6), ('더', 482), ('심하다', 39), ('이렇게', 122), ('개', 480), ('로', 1084), ('싸우다', 52), ('내', 446), ('볼', 33), ('땐', 28), ('두다', 100), ('나쁘다', 68), ('말', 613), ('이상', 84), ('이하', 19), ('고', 802), ('향가', 1), ('서', 305), ('피방', 3), ('가면', 59), ('동네', 47), ('부럴', 1), ('친구', 54), ('이랑은', 7), ('거르', 15), ('없이', 58), ('이야기', 40), ('막', 47), ('되다', 1508), ('당연하다', 105), ('키', 101), ('보드', 8), ('치다', 392), ('않다', 547), ('많이', 150), ('거치다', 4), ('해', 164), ('반성', 21), ('예수', 90), ('십', 14), ('새끼', 1766), ('개새끼', 84), ('창녀', 23), ('아들', 49), ('애비', 69), ('실종', 2), ('가정교육', 1), ('못', 773), ('무뇌충', 3), ('허언증', 3), ('정신병', 177), ('사기꾼', 24), ('망상', 22), ('근본', 17), ('없다', 1202), ('병신', 357), ('장애인', 32), ('짱개', 57), ('흑인', 45), ('이슬람', 211), ('전라도', 369), ('랑', 267), ('동', 70), ('급', 89), ('나이', 77), ('먹다', 464), ('피시방', 6), ('가다', 583), ('놈', 396), ('대가리', 61), ('똥', 198), ('만찬', 2), ('들이다', 350), ('청', 4), ('같다', 1036), ('소리', 199), ('우리나라', 145), ('계집', 9), ('의무', 27), ('적', 654), ('군대', 127), ('해결', 41), ('일이', 57), ('정신', 137), ('개조', 5), ('시키다', 349), ('지다', 433), ('하고', 636), ('무슨', 213), ('애', 453), ('낳다', 71), ('자식', 45), ('교육', 64), ('을', 2078), ('재능', 2), ('ㅂㅅㅌㅊ', 3), ('노', 184), ('ㅋㅋㅋㅋㅋ', 257), ('나다', 341), ('합성', 13), ('배우다', 65), ('가짜', 14), ('남자', 557), ('어떻다', 224), ('생기다', 220), ('뺨', 7), ('어린이집', 2), ('월요일', 1), ('데리다', 4), ('금요일', 2), ('데리', 21), ('오다', 467), ('가슴', 35), ('너무', 161), ('아프다', 30), ('작', 27), ('살', 161), ('아가', 7), ('얼마나', 111), ('외롭다', 2), ('갓슬람', 1), ('정희', 3), ('구현', 5), ('테러', 70), ('ㅅㅅㅅㅅ', 2), ('미제', 1), ('양키', 18), ('에게는', 10), ('답', 141), ('좆', 710), ('씨발', 454), ('따다', 165), ('넘어가다', 30), ('원', 79), ('리더십', 3), ('메시지', 2), ('내부', 6), ('결속', 2), ('강화하다', 5), ('외부', 10), ('리마커블', 1), ('이미지', 27), ('구축', 4), ('다시', 86), ('교회', 258), ('모', 59), ('일수', 7), ('소망', 7), ('기', 188), ('도합', 21), ('니', 478), ('협박', 14), ('스킬', 4), ('패', 97), ('시브', 4), ('랑께', 16), ('위로', 13), ('격려', 2), ('호텔', 3), ('저', 918), ('여자도', 18), ('정상', 101), ('완전', 40), ('지네', 22), ('할아버지', 4), ('많다', 436), ('데', 109), ('토나오다', 15), ('미치다', 178), ('그렇게', 102), ('더럽다', 101), ('짓다', 35), ('설교', 8), ('웩', 5), ('메틸', 4), ('알콜', 3), ('집', 118), ('쓰다', 307), ('질문', 22), ('프로', 38), ('에틸', 2), ('들어가다', 99), ('공업', 1), ('용', 17), ('면세', 1), ('라', 447), ('불법', 27), ('술', 32), ('제조', 2), ('때문', 198), ('정도', 171), ('제', 147), ('조방', 1), ('지용', 1), ('쓴다', 32), ('띄우다', 3), ('사람', 647), ('한국', 462), ('미고', 2), ('유정', 1), ('수준', 145), ('ㅋㅋㅋ', 622), ('구', 111), ('절절', 5), ('팩트', 61), ('쑈', 1), ('빼다', 55), ('아무', 81), ('것', 568), ('개돼지', 53), ('정권', 41), ('이노', 255), ('탄핵', 9), ('개힘', 2), ('조', 121), ('아주', 88), ('싫다', 216), ('외국', 73), ('년놈', 10), ('에게', 155), ('욕질', 2), ('괜히', 27), ('해대', 11), ('게', 626), ('이고', 185), ('그냥', 412), ('종교', 185), ('충', 444), ('죽다', 167), ('좋다', 497), ('홍어', 278), ('무치다', 2), ('ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 13), ('안티', 4), ('페미', 414), ('울다', 39), ('전', 141), ('설치다', 17), ('작자', 4), ('설치', 22), ('다니다', 228), ('직시', 2), ('해보다', 147), ('우선', 18), ('인', 525), ('기업', 39), ('이네', 152), ('이여', 15), ('돈', 308), ('갖다', 57), ('받치다', 3), ('어이없다', 14), ('시', 162), ('문제', 230), ('홍', 19), ('피', 89), ('폭', 5), ('ㅎㅎㅎ', 18), ('안', 934), ('희다', 24), ('정민아', 1 ...

# %%
threshold = 3
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 18182
# 등장 빈도가 2번 이하인 희귀 단어의 수: 11425
# 단어 집합에서 희귀 단어의 비율: 62.836871631283685
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 7.2689247886578405

# %%
vocab_size = total_cnt - rare_cnt + 1
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 6758

# %%
tokenizer = Tokenizer(vocab_size) # 빈도수 2 이하인 단어는 제거
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
y_train = np.array(train_data['target'])
y_test = np.array(test_data['target'])

# %%
print(len(X_train))
print(len(y_train))
# Out:
# 14980
# 14980

# %%
print(X_train[:3])
# Out:
# [[11, 440, 583, 26, 4], [1789, 1197, 4461, 824, 1887, 1544, 43, 206, 1062, 1034, 1035, 11, 113, 518, 1000, 3088, 7], [76, 73, 128, 3889, 4462, 6, 441, 32, 373, 20, 3]]

# %%
drop_train = [index for index, sentence in enumerate(X_train) if len(sentence) < 1]
drop_test = [index for index, sentence in enumerate(X_test) if len(sentence) < 1]

# %%
print(drop_train)
# Out:
# [182, 382, 974, 1090, 1204, 1608, 1795, 2058, 2310, 2389, 2740, 2819, 2957, 3098, 3164, 3277, 3497, 3598, 3601, 3772, 3904, 4310, 4542, 5193, 6153, 6675, 6765, 7088, 7201, 7495, 7507, 7593, 7983, 8198, 8835, 9657, 10622, 12115, 12117, 12148, 12405, 12558, 12622, 12643, 12839, 12930, 13197, 13207, 13333, 13423, 13710, 13998, 14016, 14063]

# %%
len(drop_train)
# Out:
# 54

# %%
X_train = np.delete(X_train, drop_train, axis=0)
y_train = np.delete(y_train, drop_train, axis=0)
# Out:
# C:\Users\jisoo\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
print(len(X_train))
print(len(y_train))
# Out:
# 14926
# 14926

# %%
print(len(X_test))
print(len(y_test))
# Out:
# 3730
# 3730

# %%
X_test = np.delete(X_test, drop_test, axis=0)

# %%
y_test = np.delete(y_test, drop_test, axis=0)

# %%
print(len(X_test))
print(len(y_test))
# Out:
# 3713
# 3713

# %%
print('문장의 최대 길이 :',max(len(l) for l in X_train))
print('문장의 평균 길이 :',sum(map(len, X_train))/len(X_train))
plt.hist([len(s) for s in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 72
# 리뷰의 평균 길이 : 11.971727187458127

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))*100))

# %%
max_len = 30
below_threshold_len(max_len, X_train)
# Out:
# 전체 샘플 중 길이가 30 이하인 샘플의 비율: 95.0623073830899

# %%
# 전체 데이터의 길이는 30으로 맞춘다.
X_train = pad_sequences(X_train, maxlen = max_len)
X_test = pad_sequences(X_test, maxlen = max_len)

# %% [markdown]
# # 2. Multi-Kernel 1D CNN으로 혐오 발언 분류하기

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Embedding, Dropout, Conv1D, GlobalMaxPooling1D, Dense, Input, Flatten, Concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model

# %%
embedding_dim = 128
dropout_ratio = (0.5, 0.8)
num_filters = 128
hidden_units = 128

# %%
model_input = Input(shape = (max_len,))
z = Embedding(vocab_size, embedding_dim, input_length = max_len, name="embedding")(model_input)
z = Dropout(dropout_ratio[0])(z)

# %%
conv_blocks = []

for sz in [3, 4, 5]:
    conv = Conv1D(filters = num_filters,
                         kernel_size = sz,
                         padding = "valid",
                         activation = "relu",
                         strides = 1)(z)
    conv = GlobalMaxPooling1D()(conv)
    conv_blocks.append(conv)

# %%
z = Concatenate()(conv_blocks) if len(conv_blocks) > 1 else conv_blocks[0]
z = Dropout(dropout_ratio[1])(z)
z = Dense(hidden_units, activation="relu")(z)
model_output = Dense(1, activation="sigmoid")(z)

model = Model(model_input, model_output)
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["acc"])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 30, 128)      865024      input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 30, 128)      0           embedding[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 28, 128)      49280       dropout[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 27, 128)      65664       dropout[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 26, 128)      82048       dropout[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 128)          0           conv1d[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalM (None, 128)          0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_2 (GlobalM (None, 128)          0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 384)          0           global_max_pooling1d[0][0]
#                                                                  global_max_pooling1d_1[0][0]
#                                                                  global_max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 384)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          49280       dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            129         dense[0][0]
# ==================================================================================================
# Total params: 1,111,425
# Trainable params: 1,111,425
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('CNN_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

model.fit(X_train, y_train, batch_size = 64, epochs=10, validation_split = 0.2, verbose=2, callbacks=[es, mc])
# Out:
# Epoch 1/10
# 187/187 - 5s - loss: 0.4740 - acc: 0.7678 - val_loss: 0.4001 - val_acc: 0.8145
#
# Epoch 00001: val_acc improved from -inf to 0.81447, saving model to CNN_model.h5
# Epoch 2/10
# 187/187 - 4s - loss: 0.3385 - acc: 0.8464 - val_loss: 0.3704 - val_acc: 0.8272
#
# Epoch 00002: val_acc improved from 0.81447 to 0.82719, saving model to CNN_model.h5
# Epoch 3/10
# 187/187 - 4s - loss: 0.2670 - acc: 0.8835 - val_loss: 0.3887 - val_acc: 0.8218
#
# Epoch 00003: val_acc did not improve from 0.82719
# Epoch 4/10
# 187/187 - 4s - loss: 0.2224 - acc: 0.9101 - val_loss: 0.4170 - val_acc: 0.8212
#
# Epoch 00004: val_acc did not improve from 0.82719
# Epoch 5/10
# 187/187 - 4s - loss: 0.1895 - acc: 0.9221 - val_loss: 0.4623 - val_acc: 0.8218
#
# Epoch 00005: val_acc did not improve from 0.82719
# Epoch 6/10
# 187/187 - 4s - loss: 0.1605 - acc: 0.9348 - val_loss: 0.5159 - val_acc: 0.8131
#
# Epoch 00006: val_acc did not improve from 0.82719
# Epoch 00006: early stopping

# %%
loaded_model = load_model('CNN_model.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))
# Out:
# 117/117 [==============================] - ETA: 0s - loss: 0.3660 - acc: 0.826 - 0s 3ms/step - loss: 0.3649 - acc: 0.8271
#
#  테스트 정확도: 0.8271

# %%
from keras.models import load_model

model.save('my_model.h5')  # creates a HDF5 file 'my_model.h5'
del model  # deletes the existing model

# returns a compiled model
# identical to the previous one
model = load_model('my_model.h5')

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score

clf = LogisticRegression(solver="liblinear", random_state=0).fit(X_test, y_test)

# roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1]) 
AUC = roc_auc_score(y_test, clf.decision_function(X_test))     

y_pred = model.predict(X_test)
precision = precision_score(y_test, np.round(abs(y_pred))) 
f1 = f1_score(y_test, np.round(abs(y_pred))) 

print("AUC : ", AUC)
print("Precision Score : ", precision)
print("f1 Score : ", f1)
# Out:
# AUC :  0.6494465435060818
# Precision Score :  0.8607681755829903
# f1 Score :  0.8783902012248469

# %% [markdown]
# # 3. 혐오 발언 예측해보기

# %%
def sentiment_predict(new_sentence):
  new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
  new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
  pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
  score = float(loaded_model.predict(pad_new)) # 예측
  if(score > 0.5):
    print("{:.2f}% 확률로 혐오 발언입니다.\n".format(score * 100))
  else:
    print("{:.2f}% 확률로 일반 발언입니다.\n".format((1 - score) * 100))

# %%
sentiment_predict('아이스크림 먹고싶다')
# Out:
# 65.64% 확률로 일반 발언입니다.

# %%
sentiment_predict('야 이 나쁜 놈아')
# Out:
# 64.23% 확률로 혐오 발언입니다.
